# %% [markdown]
# ## Data Extraction,Transforming and Loading using Pandas and ProsgreSQL
#
# In this project the basics of ETL shall be explored.
#
# This is a dataset from [Kaggle](https://www.kaggle.com/rounakbanik/the-movies-dataset#ratings_small.csv),and detailed decription of the dataset can also be found [here](https://grouplens.org/datasets/movielens/latest/)
#
#
# ### Project Tasks includes:
#
# * Data extraction from csv files into pandas DataFrame.
#
# * Transformation and grouping of data
#
# * Create database and tables in Postgres.
#
# * Load pandas dataframe into the Database.
#
# * Query Database

# %%
import pandas as pd
import matplotlib as plt
import psycopg2
from sqlalchemy import create_engine
import os

from datetime import datetime
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## **Extraction and Transformation**
#
# ### **First Dataset**

# %%
df_links = pd.read_csv('links.csv')
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
#Check for missing values
df_links.isnull().sum()

#Drop all missing values
df_links.dropna()

df_links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %% [markdown]
# #### Using Idenfiers we generate the movie links, by appending the IMDB/TMDB links to the imdbid/tmdbid respectively for each movie.
# For IMDB Link = 'http://www.imdb.com/title/tt***'
#
# The *** or IMDB ID in the actual hyperlink requires a 7 digit ID. So in the dataset, wherever we have 6 digits in the 'imdbid' column, we are appending '0' before the id in the link. For a 7 digit 'imdbid', no changes are required.
#
# For TMDB Link= 'https://www.themoviedb.org/movie/***'
#
# Replace the astericts with the TMDB ID value.

# %%
# Create a copy of the Dataset

df_links_copy = df_links.copy()

# %%
# Fill the NA in the tmbId colunm with 0 and change to interger
df_links['tmdbId'] = df_links['tmdbId'].fillna(0).astype(int)

# %%
# Add new columns to Create IMDB link 
df_links['IMDB_link'] = df_links.apply(lambda row: "https://www.imdb.com/title/tt0" + "0" * (6 - len(str(row.imdbId))) + str(row.imdbId), axis = 1)
df_links.tail()
# Out:
#       movieId   imdbId  tmdbId                              IMDB_link
# 9737   193581  5476944  432131  https://www.imdb.com/title/tt05476944
# 9738   193583  5914996  445030  https://www.imdb.com/title/tt05914996
# 9739   193585  6397426  479308  https://www.imdb.com/title/tt06397426
# 9740   193587  8391976  483455  https://www.imdb.com/title/tt08391976
# 9741   193609   101726   37891   https://www.imdb.com/title/tt0101726

# %%
# Add new columns to Create TMDB link 
df_links['TMDB_link'] = df_links.apply(lambda row: "https://www.themoviedb.org/movie/" + str(row.tmdbId), axis = 1)
df_links.tail()
# Out:
#       movieId   imdbId  tmdbId                              IMDB_link  \
# 9737   193581  5476944  432131  https://www.imdb.com/title/tt05476944
# 9738   193583  5914996  445030  https://www.imdb.com/title/tt05914996
# 9739   193585  6397426  479308  https://www.imdb.com/title/tt06397426
# 9740   193587  8391976  483455  https://www.imdb.com/title/tt08391976
# 9741   193609   101726   37891   https://www.imdb.com/title/tt0101726
#
#                                     TMDB_link
# 9737  https://www.themoviedb.org/movie/432131
# 9738  https://www.themoviedb.org/movie/445030
# 9739  https://www.themoviedb.org/movie/479308
# 9740  https://www.themoviedb.org/movie/483455
# 9741   https://www.themoviedb.org/movie/37891

# %% [markdown]
# ### **Second dataset**

# %%
df_movies = pd.read_csv('movies.csv')

# %%
#Check for missing values
df_movies.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
# Create a copy of the Dataset
df_movies_copy = df_movies.copy()

# %% [markdown]
# Extract year of release from the title and create a new column 'year_of_release'

# %%
#Replace delimiter in title column with space
df_movies["title"] = df_movies["title"].str.replace(',','')

#Split title column into two 
split = df_movies["title"].str.rsplit("(", n = 1, expand = True)
df_movies["Title"] = split[0]
df_movies["Year_of_Release "] = split[1]

#Drop the previous title column
df_movies = df_movies.drop('title',axis = 1,inplace = False)

#Replace demiliters with space
df_movies["Year_of_Release "] = df_movies["Year_of_Release "].str.replace(')','')


#rearrange the column
df_movies.rename(columns={"genres": "Genres"},inplace = True)
df_movies = df_movies[['movieId', 'Title', 'Genres','Year_of_Release ']]

#df_movies = df_movies.set_index('movieId')

df_movies
# Out:
#       movieId                                Title  \
# 0           1                           Toy Story
# 1           2                             Jumanji
# 2           3                    Grumpier Old Men
# 3           4                   Waiting to Exhale
# 4           5         Father of the Bride Part II
# ...       ...                                  ...
# 9737   193581  Black Butler: Book of the Atlantic
# 9738   193583               No Game No Life: Zero
# 9739   193585                               Flint
# 9740   193587        Bungo Stray Dogs: Dead Apple
# 9741   193609        Andrew Dice Clay: Dice Rules
#
#                                            Genres Year_of_Release
# 0     Adventure|Animation|Children|Comedy|Fantasy             1995
# 1                      Adventure|Children|Fantasy             1995
# 2                                  Comedy|Romance             1995
# 3                            Comedy|Drama|Romance             1995
# 4                                          Comedy             1995
# ...                                           ...              ...
# 9737              Action|Animation|Comedy|Fantasy             2017
# 9738                     Animation|Comedy|Fantasy             2017
# 9739                                        Drama             2017
# 9740                             Action|Animation             2018
# 9741                                       Comedy             1991
#
# [9742 rows x 4 columns]

# %%
df_movies['Title'].head(10)
# Out:
# 0                      Toy Story
# 1                        Jumanji
# 2               Grumpier Old Men
# 3              Waiting to Exhale
# 4    Father of the Bride Part II
# 5                           Heat
# 6                        Sabrina
# 7                   Tom and Huck
# 8                   Sudden Death
# 9                      GoldenEye
# Name: Title, dtype: object

# %% [markdown]
# ### Third Dtaset

# %%
df_ratings = pd.read_csv('ratings.csv')
df_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
#Check for missing values
df_ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
# Create a copy of the Dataset
df_ratings_copy = df_ratings.copy()

#Convert time  the time to datatime format
df_ratings['timestamp'] = df_ratings['timestamp'].apply(lambda x:datetime.utcfromtimestamp(x ).strftime('%Y-%m-%d %H:%M:%S'))

# %% [markdown]
# Since a movie can be rated by multiple users and likewise a user can rate multiple movies,we group the rating of each movie based on their id and calculate the mean.

# %%
mean_df_ratings = df_ratings.groupby('movieId').mean().reset_index()

#drop userid
mean_df_ratings= mean_df_ratings.drop('userId',axis = 1)

mean_df_ratings
# Out:
#       movieId    rating
# 0           1  3.920930
# 1           2  3.431818
# 2           3  3.259615
# 3           4  2.357143
# 4           5  3.071429
# ...       ...       ...
# 9719   193581  4.000000
# 9720   193583  3.500000
# 9721   193585  3.500000
# 9722   193587  3.500000
# 9723   193609  4.000000
#
# [9724 rows x 2 columns]

# %%
#Todo: group movieId rating by total number of users that gave it a  particular rating
agg_df_ratings = df_ratings.groupby(['movieId','rating'])['userId'].agg(sum).reset_index()


agg_df_ratings
# Out:
#        movieId  rating  userId
# 0            1     0.5      76
# 1            1     1.5     462
# 2            1     2.0    1454
# 3            1     2.5    2939
# 4            1     3.0    9719
# ...        ...     ...     ...
# 30412   193581     4.0     184
# 30413   193583     3.5     184
# 30414   193585     3.5     184
# 30415   193587     3.5     184
# 30416   193609     4.0     331
#
# [30417 rows x 3 columns]

# %% [markdown]
# ### **Fourth dataset**

# %%
df_tags = pd.read_csv('tags.csv')
df_tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
#Check for missing values
df_tags.isnull().sum()

#Convert time  the time to datatime format
df_tags['timestamp'] = df_tags['timestamp'].apply(lambda x:datetime.utcfromtimestamp(x ).strftime('%Y-%m-%d %H:%M:%S'))

#create a copy
df_tags_copy = df_tags.copy()

# %%
#Aggregate the tags associated with each movieId
df_tags_new = df_tags.groupby('movieId')['tag'].agg(set).reset_index()

#Convert tags from set to strings seperated by space
df_tags_new['tag_new'] = df_tags_new['tag'].apply(lambda x:' '.join(x))

#Rearrange column
df_tags_new = df_tags_new.drop('tag',axis = 1)
df_tags_new.rename(columns={"tag_new":"Tag"},inplace = True)


df_tags_new
# Out:
#       movieId                                              Tag
# 0           1                                        pixar fun
# 1           2     fantasy game Robin Williams magic board game
# 2           3                                        moldy old
# 3           5                                 remake pregnancy
# 4           7                                           remake
# ...       ...                                              ...
# 1567   183611                      funny Comedy Rachel McAdams
# 1568   184471  adventure video game adaptation Alicia Vikander
# 1569   187593                sarcasm Josh Brolin Ryan Reynolds
# 1570   187595                          Emilia Clarke star wars
# 1571   193565                    comedy gintama anime remaster
#
# [1572 rows x 2 columns]

# %% [markdown]
# ###  Merge all dataframes into into a singe csv file

# %%
#Join all dataframes based on the movieid column
dfs = [df_movies, df_links, mean_df_ratings,df_tags_new]
dfs = [df.set_index('movieId') for df in dfs]


df_final = pd.concat(dfs,axis = 1)

#Replace all NaN with a space
df_final.fillna(' ',inplace = True)

#save as csv file
final_csv = "./df_final.csv"
df_final.to_csv(final_csv)
df_final.tail(10)
# Out:
#                                                     Title  \
# movieId
# 193565                                Gintama: The Movie
# 193567   anohana: The Flower We Saw That Day - The Movie
# 193571                                      Silver Spoon
# 193573                  Love Live! The School Idol Movie
# 193579                 Jon Stewart Has Left the Building
# 193581                Black Butler: Book of the Atlantic
# 193583                             No Game No Life: Zero
# 193585                                             Flint
# 193587                      Bungo Stray Dogs: Dead Apple
# 193609                      Andrew Dice Clay: Dice Rules
#
#                                   Genres Year_of_Release    imdbId  tmdbId  \
# movieId
# 193565    Action|Animation|Comedy|Sci-Fi             2010  1636780   71172
# 193567                   Animation|Drama             2013  2323836  255413
# 193571                      Comedy|Drama             2014  3110014  297825
# 193573                         Animation             2015  3837248  333623
# 193579                       Documentary             2015  5342766  360617
# 193581   Action|Animation|Comedy|Fantasy             2017  5476944  432131
# 193583          Animation|Comedy|Fantasy             2017  5914996  445030
# 193585                             Drama             2017  6397426  479308
# 193587                  Action|Animation             2018  8391976  483455
# 193609                            Comedy             1991   101726   37891
#
#                                      IMDB_link  \
# movieId
# 193565   https://www.imdb.com/title/tt01636780
# 193567   https://www.imdb.com/title/tt02323836
# 193571   https://www.imdb.com/title/tt03110014
# 193573   https://www.imdb.com/title/tt03837248
# 193579   https://www.imdb.com/title/tt05342766
# 193581   https://www.imdb.com/title/tt05476944
# 193583   https://www.imdb.com/title/tt05914996
# 193585   https://www.imdb.com/title/tt06397426
# 193587   https://www.imdb.com/title/tt08391976
# 193609    https://www.imdb.com/title/tt0101726
#
#                                        TMDB_link rating  \
# movieId
# 193565    https://www.themoviedb.org/movie/71172    3.5
# 193567   https://www.themoviedb.org/movie/255413      3
# 193571   https://www.themoviedb.org/movie/297825      4
# 193573   https://www.themoviedb.org/movie/333623      4
# 193579   https://www.themoviedb.org/movie/360617    3.5
# 193581   https://www.themoviedb.org/movie/432131      4
# 193583   https://www.themoviedb.org/movie/445030    3.5
# 193585   https://www.themoviedb.org/movie/479308    3.5
# 193587   https://www.themoviedb.org/movie/483455    3.5
# 193609    https://www.themoviedb.org/movie/37891      4
#
#                                    Tag
# movieId
# 193565   comedy gintama anime remaster
# 193567
# 193571
# 193573
# 193579
# 193581
# 193583
# 193585
# 193587
# 193609

# %%
# dropping ALL duplicte values if any 
df_final.drop_duplicates( keep = False, inplace = True)

# %% [markdown]
# ### Loading transformed data into Postgres database
#
# ###  Pre-requitsite
# Create database on Postgres, Enter the command : **CREATE DATABASE moviedb;**
#
#
# Next:
#
# * connect to database using conncetion parameters (user,host,password and databaseName)
# * create table
# * Load dataframe in bulk into moviedb

# %%
#Postgres Connection parameters
params = {
    "host"      : "127.0.0.1",
    "database"  : "moviedb",
    "user"      : "postgres",
    "password"  : "Enter your password "}

# %%
#Function to connect to database   
def connect(params):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        
    print("Connection successful")     
    return conn

# %%
#Test connection
conn = connect(params)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %%
#Function to Close connection

def close_connection(connection):
    if conn:
        conn.close()
    return print('Connection closed')

# %%
close_connection(conn)

# %%
#Function to execute query

def execute_query(conn, query):
    """ Execute a single query """
    
    ret = 0 # Return value
    cursor = conn.cursor()
    try:
        cursor.execute(query)
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1                                                                                                                                                                                                                                                                                                                                                                       

    # If this was a select query, return the result
    if 'select' in query.lower():
        ret = cursor.fetchall()
    cursor.close()
    print ('Query executed')
    return ret

# %%
def create_tables():
    """ create tables in the PostgreSQL database"""
    table = (
        """
        CREATE TABLE Movie_data (
            movieId INTEGER PRIMARY KEY,
            Genres VARCHAR ,
            Title VARCHAR ,
            Year_of_Release VARCHAR,
            imdbid VARCHAR ,
            tmdid VARCHAR ,
            IMBD_link VARCHAR ,
            TMBD_link VARCHAR ,
            rating VARCHAR,
            Tag VARCHAR 
                
        )
        """)
    conn = None
    try:
        
        # connect to the PostgreSQL server
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        # create table 
        cur.execute(table)
        # close communication with the PostgreSQL database server
        cur.close()
        # commit the changes
        conn.commit()
        print("Table created successfully in PostgreSQL ")
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
def copy_from_file(conn, df, table):
    """
    Here we are going save the dataframe on disk as 
    a csv file, load the csv file  
    and use copy_from() to copy it to the table
    """
    # Save the dataframe to disk
    tmp_df = "./tmp_df.csv"
    df.to_csv(tmp_df)
    cursor = conn.cursor()
    with open(tmp_df, 'r',encoding='utf-8',errors='ignore') as f:
        try:
            next(f) # Skip the header row.
            cursor.copy_from(f, table, sep=",",null="")
            conn.commit()
        except (Exception, psycopg2.DatabaseError) as error:
            os.remove(tmp_df)
            print("Error: %s" % error)
            conn.rollback()
            cursor.close()
            return 1
        print("File copied into Database")
    
    cursor.close()
    os.remove(tmp_df)
    print("%s has been removed successfully" %tmp_df)

# %%
create_tables()
# Out:
# relation "movie_data" already exists

# %%
#Bulk Load csv into the database

copy_from_file(conn, df_final,'movie_data')
# Out:
# File copied into Database
# ./tmp_df.csv has been removed successfully

# %% [markdown]
# ### Run some querys on the Database

# %%
##Select all the data in the table
execute_query(conn, 'SELECT * FROM movie_data;')
# Out:
# Query executed
# [(1,
#   'Toy Story ',
#   'Adventure|Animation|Children|Comedy|Fantasy',
#   '1995',
#   '114709',
#   '862',
#   'https://www.imdb.com/title/tt0114709',
#   'https://www.themoviedb.org/movie/862',
#   '3.9209302325581397',
#   'pixar fun'),
#  (2,
#   'Jumanji ',
#   'Adventure|Children|Fantasy',
#   '1995',
#   '113497',
#   '8844',
#   'https://www.imdb.com/title/tt0113497',
#   'https://www.themoviedb.org/movie/8844',
#   '3.4318181818181817',
#   'Robin Williams game magic board game fantasy'),
#  (3,
#   'Grumpier Old Men ',
#   'Comedy|Romance',
#   '1995',
#   '113228',
#   '15602',
#   'https://www.imdb.com/title/tt0113228',
#   'https://www.themoviedb.org/movie/15602',
#   '3.2596153846153846',
#   'moldy old'),
#  (4,
#   'Waiting to Exhale ',
#   'Comedy|Drama|Romance',
#   '1995',
#   '114885',
#   '31357',
#   'https://www.imdb.com/title/tt0114885',
#   'https://www.themoviedb.org/movie/31357',
#   '2.357142857142857',
#   ' '),
#  (5,
#   'Father of the Bride Part II ',
#   'Comedy',
#   '1995',
#   '113041',
#   '11862',
#   'https://www.imdb.com/title/tt0113041',
#   'https://www.themoviedb.org/movie/11862',
#   '3.0714285714285716',
#   'remake pregnancy'),
#  (6,
#   'Heat ',
#   'Action|Crime|Thriller',
#   '1995',
#   '113277',
#   '949',
#   'https://www.imdb.com/title/tt0113277',
#   'https://www.themoviedb.org/movie/949',
#   '3.946078431372549',
#   ' '),
#  (7,
#   'Sabrina ',
#   'Comedy|Romance',
#   '1995',
#   '114319',
#   '11860',
#   'https://www.imdb.com/title/tt0114319',
#   'https://www.themoviedb.org/movie/11860',
#   '3.185185185185185',
#   'remake'),
#  (8,
#   'Tom and Huck ',
#   'Adventure|Children',
#   '1995',
#   '112302',
#   '45325',
#   'https://www.imdb.com/title/tt0112302',
#   'https://www.themoviedb.org/movie/45325',
#   '2.875',
#   ' '),
#  (9,
#   'Sudden Death ',
#   'Action',
#   '1995',
#   '114576',
#   '9091',
#   'https://www.imdb.com/title/tt0114576',
#   'https://www.themoviedb.org/movie/9091',
#   '3.125',
#   ' '),
#  (10,
#   'GoldenEye ',
#   'Action|Adventure|Thriller',
#   '1995',
#   '113189',
#   '710',
#   'https://www.imdb.com/title/tt0113189',
#   'https://www.themoviedb.org/movie/710',
#   '3.496212121212121',
#   ' '),
#  (11,
#   'American President The ',
#   'Comedy|Drama|Romance',
#   '1995',
#   '112346',
#   '9087',
#   'https://www.imdb.com/title/tt0112346',
#   'https://www.themoviedb.org/movie/9087',
#   '3.6714285714285713',
#   'president politics'),
#  (12,
#   'Dracula: Dead and Loving It ',
#   'Comedy|Horror',
#   '1995',
#   '112896',
#   '12110',
#   'https://www.imdb.com/title/tt0112896',
#   'https://www.themoviedb.org/movie/12110',
#   '2.4210526315789473',
#   ' '),
#  (13,
#   'Balto ',
#   'Adventure|Animation|Children',
#   '1995',
#   '112453',
#   '21032',
#   'https://www.imdb.com/title/tt0112453',
#   'https://www.themoviedb.org/movie/21032',
#   '3.125',
#   ' '),
#  (14,
#   'Nixon ',
#   'Drama',
#   '1995',
#   '113987',
#   '10858',
#   'https://www.imdb.com/title/tt0113987',
#   'https://www.themoviedb.org/movie/10858',
#   '3.8333333333333335',
#   'president politics'),
#  (15,
#   'Cutthroat Island ',
#   'Action|Adventure|Romance',
#   '1995',
#   '112760',
#   '1408',
#   'https://www.imdb.com/title/tt0112760',
#   'https://www.themoviedb.org/movie/1408',
#   '3.0',
#   ' '),
#  (16,
#   'Casino ',
#   'Crime|Drama',
#   '1995',
#   '112641',
#   '524',
#   'https://www.imdb.com/title/tt0112641',
#   'https://www.themoviedb.org/movie/524',
#   '3.926829268292683',
#   'Mafia'),
#  (17,
#   'Sense and Sensibility ',
#   'Drama|Romance',
#   '1995',
#   '114388',
#   '4584',
#   'https://www.imdb.com/title/tt0114388',
#   'https://www.themoviedb.org/movie/4584',
#   '3.7761194029850746',
#   'Jane Austen'),
#  (18,
#   'Four Rooms ',
#   'Comedy',
#   '1995',
#   '113101',
#   '5',
#   'https://www.imdb.com/title/tt0113101',
#   'https://www.themoviedb.org/movie/5',
#   '3.7',
#   ' '),
#  (19,
#   'Ace Ventura: When Nature Calls ',
#   'Comedy',
#   '1995',
#   '112281',
#   '9273',
#   'https://www.imdb.com/title/tt0112281',
#   'https://www.themoviedb.org/movie/9273',
#   '2.727272727272727',
#   ' '),
#  (20,
#   'Money Train ',
#   'Action|Comedy|Crime|Drama|Thriller',
#   '1995',
#   '113845',
#   '11517',
#   'https://www.imdb.com/title/tt0113845',
#   'https://www.themoviedb.org/movie/11517',
#   '2.5',
#   ' '),
#  (21,
#   'Get Shorty ',
#   'Comedy|Crime|Thriller',
#   '1995',
#   '113161',
#   '8012',
#   'https://www.imdb.com/title/tt0113161',
#   'https://www.themoviedb.org/movie/8012',
#   '3.49438202247191',
#   'Hollywood'),
#  (22,
#   'Copycat ',
#   'Crime|Drama|Horror|Mystery|Thriller',
#   '1995',
#   '112722',
#   '1710',
#   'https://www.imdb.com/title/tt0112722',
#   'https://www.themoviedb.org/movie/1710',
#   '3.2222222222222223',
#   'serial killer'),
#  (23,
#   'Assassins ',
#   'Action|Crime|Thriller',
#   '1995',
#   '112401',
#   '9691',
#   'https://www.imdb.com/title/tt0112401',
#   'https://www.themoviedb.org/movie/9691',
#   '3.125',
#   ' '),
#  (24,
#   'Powder ',
#   'Drama|Sci-Fi',
#   '1995',
#   '114168',
#   '12665',
#   'https://www.imdb.com/title/tt0114168',
#   'https://www.themoviedb.org/movie/12665',
#   '3.125',
#   ' '),
#  (25,
#   'Leaving Las Vegas ',
#   'Drama|Romance',
#   '1995',
#   '113627',
#   '451',
#   'https://www.imdb.com/title/tt0113627',
#   'https://www.themoviedb.org/movie/451',
#   '3.625',
#   'alcoholism'),
#  (26,
#   'Othello ',
#   'Drama',
#   '1995',
#   '114057',
#   '16420',
#   'https://www.imdb.com/title/tt0114057',
#   'https://www.themoviedb.org/movie/16420',
#   '3.5',
#   'Shakespeare'),
#  (27,
#   'Now and Then ',
#   'Children|Drama',
#   '1995',
#   '114011',
#   '9263',
#   'https://www.imdb.com/title/tt0114011',
#   'https://www.themoviedb.org/movie/9263',
#   '3.3333333333333335',
#   ' '),
#  (28,
#   'Persuasion ',
#   'Drama|Romance',
#   '1995',
#   '114117',
#   '17015',
#   'https://www.imdb.com/title/tt0114117',
#   'https://www.themoviedb.org/movie/17015',
#   '4.2272727272727275',
#   'Jane Austen In Netflix queue'),
#  (29,
#   'City of Lost Children The (Cité des enfants perdus La) ',
#   'Adventure|Drama|Fantasy|Mystery|Sci-Fi',
#   '1995',
#   '112682',
#   '902',
#   'https://www.imdb.com/title/tt0112682',
#   'https://www.themoviedb.org/movie/902',
#   '4.0131578947368425',
#   'kidnapping'),
#  (30,
#   'Shanghai Triad (Yao a yao yao dao waipo qiao) ',
#   'Crime|Drama',
#   '1995',
#   '115012',
#   '37557',
#   'https://www.imdb.com/title/tt0115012',
#   'https://www.themoviedb.org/movie/37557',
#   '3.0',
#   ' '),
#  (31,
#   'Dangerous Minds ',
#   'Drama',
#   '1995',
#   '112792',
#   '9909',
#   'https://www.imdb.com/title/tt0112792',
#   'https://www.themoviedb.org/movie/9909',
#   '3.1842105263157894',
#   'teacher high school'),
#  (32,
#   'Twelve Monkeys (a.k.a. 12 Monkeys) ',
#   'Mystery|Sci-Fi|Thriller',
#   '1995',
#   '114746',
#   '63',
#   'https://www.imdb.com/title/tt0114746',
#   'https://www.themoviedb.org/movie/63',
#   '3.983050847457627',
#   'remake mindfuck post-apocalyptic twist ending time travel Bruce Willis Post apocalyptic Brad Pitt'),
#  (34,
#   'Babe ',
#   'Children|Drama',
#   '1995',
#   '112431',
#   '9598',
#   'https://www.imdb.com/title/tt0112431',
#   'https://www.themoviedb.org/movie/9598',
#   '3.65234375',
#   'Animal movie pigs villain nonexistent or not needed for good story'),
#  (36,
#   'Dead Man Walking ',
#   'Crime|Drama',
#   '1995',
#   '112818',
#   '687',
#   'https://www.imdb.com/title/tt0112818',
#   'https://www.themoviedb.org/movie/687',
#   '3.8358208955223883',
#   'death penalty Nun'),
#  (38,
#   'It Takes Two ',
#   'Children|Comedy',
#   '1995',
#   '113442',
#   '33689',
#   'https://www.imdb.com/title/tt0113442',
#   'https://www.themoviedb.org/movie/33689',
#   '2.125',
#   'twins'),
#  (39,
#   'Clueless ',
#   'Comedy|Romance',
#   '1995',
#   '112697',
#   '9603',
#   'https://www.imdb.com/title/tt0112697',
#   'https://www.themoviedb.org/movie/9603',
#   '3.293269230769231',
#   'seen more than once Paul Rudd Jane Austen chick flick Emma quotable funny'),
#  (40,
#   'Cry the Beloved Country ',
#   'Drama',
#   '1995',
#   '112749',
#   '34615',
#   'https://www.imdb.com/title/tt0112749',
#   'https://www.themoviedb.org/movie/34615',
#   '4.25',
#   'South Africa In Netflix queue'),
#  (41,
#   'Richard III ',
#   'Drama|War',
#   '1995',
#   '114279',
#   '31174',
#   'https://www.imdb.com/title/tt0114279',
#   'https://www.themoviedb.org/movie/31174',
#   '3.7',
#   'Shakespeare'),
#  (42,
#   'Dead Presidents ',
#   'Action|Crime|Drama',
#   '1995',
#   '112819',
#   '11443',
#   'https://www.imdb.com/title/tt0112819',
#   'https://www.themoviedb.org/movie/11443',
#   '3.0',
#   ' '),
#  (43,
#   'Restoration ',
#   'Drama',
#   '1995',
#   '114272',
#   '35196',
#   'https://www.imdb.com/title/tt0114272',
#   'https://www.themoviedb.org/movie/35196',
#   '3.1875',
#   'England'),
#  (44,
#   'Mortal Kombat ',
#   'Action|Adventure|Fantasy',
#   '1995',
#   '113855',
#   '9312',
#   'https://www.imdb.com/title/tt0113855',
#   'https://www.themoviedb.org/movie/9312',
#   '2.5434782608695654',
#   ' '),
#  (45,
#   'To Die For ',
#   'Comedy|Drama|Thriller',
#   '1995',
#   '114681',
#   '577',
#   'https://www.imdb.com/title/tt0114681',
#   'https://www.themoviedb.org/movie/577',
#   '3.3125',
#   'Journalism'),
#  (97,
#   'Hate (Haine La) ',
#   'Crime|Drama',
#   '1995',
#   '113247',
#   '406',
#   'https://www.imdb.com/title/tt0113247',
#   'https://www.themoviedb.org/movie/406',
#   '3.9',
#   ' '),
#  (46,
#   'How to Make an American Quilt ',
#   'Drama|Romance',
#   '1995',
#   '113347',
#   '11861',
#   'https://www.imdb.com/title/tt0113347',
#   'https://www.themoviedb.org/movie/11861',
#   '3.066666666666667',
#   'wedding'),
#  (47,
#   'Seven (a.k.a. Se7en) ',
#   'Mystery|Thriller',
#   '1995',
#   '114369',
#   '807',
#   'https://www.imdb.com/title/tt0114369',
#   'https://www.themoviedb.org/movie/807',
#   '3.9753694581280787',
#   'mystery serial killer twist ending'),
#  (48,
#   'Pocahontas ',
#   'Animation|Children|Drama|Musical|Romance',
#   '1995',
#   '114148',
#   '10530',
#   'https://www.imdb.com/title/tt0114148',
#   'https://www.themoviedb.org/movie/10530',
#   '3.1470588235294117',
#   ' '),
#  (49,
#   'When Night Is Falling ',
#   'Drama|Romance',
#   '1995',
#   '114916',
#   '8391',
#   'https://www.imdb.com/title/tt0114916',
#   'https://www.themoviedb.org/movie/8391',
#   '3.0',
#   ' '),
#  (50,
#   'Usual Suspects The ',
#   'Crime|Mystery|Thriller',
#   '1995',
#   '114814',
#   '629',
#   'https://www.imdb.com/title/tt0114814',
#   'https://www.themoviedb.org/movie/629',
#   '4.237745098039215',
#   'mindfuck suspense twist ending thriller heist tricky'),
#  (52,
#   'Mighty Aphrodite ',
#   'Comedy|Drama|Romance',
#   '1995',
#   '113819',
#   '11448',
#   'https://www.imdb.com/title/tt0113819',
#   'https://www.themoviedb.org/movie/11448',
#   '3.4642857142857144',
#   'adoption prostitution'),
#  (53,
#   'Lamerica ',
#   'Adventure|Drama',
#   '1994',
#   '110299',
#   '49133',
#   'https://www.imdb.com/title/tt0110299',
#   'https://www.themoviedb.org/movie/49133',
#   '5.0',
#   ' '),
#  (54,
#   'Big Green The ',
#   'Children|Comedy',
#   '1995',
#   '112499',
#   '26441',
#   'https://www.imdb.com/title/tt0112499',
#   'https://www.themoviedb.org/movie/26441',
#   '2.3333333333333335',
#   ' '),
#  (55,
#   'Georgia ',
#   'Drama',
#   '1995',
#   '113158',
#   '97406',
#   'https://www.imdb.com/title/tt0113158',
#   'https://www.themoviedb.org/movie/97406',
#   '4.0',
#   ' '),
#  (57,
#   'Home for the Holidays ',
#   'Drama',
#   '1995',
#   '113321',
#   '9089',
#   'https://www.imdb.com/title/tt0113321',
#   'https://www.themoviedb.org/movie/9089',
#   '3.0625',
#   ' '),
#  (58,
#   'Postman The (Postino Il) ',
#   'Comedy|Drama|Romance',
#   '1994',
#   '110877',
#   '11010',
#   'https://www.imdb.com/title/tt0110877',
#   'https://www.themoviedb.org/movie/11010',
#   '4.027027027027027',
#   'writing'),
#  (60,
#   'Indian in the Cupboard The ',
#   'Adventure|Children|Fantasy',
#   '1995',
#   '113419',
#   '11359',
#   'https://www.imdb.com/title/tt0113419',
#   'https://www.themoviedb.org/movie/11359',
#   '3.235294117647059',
#   ' '),
#  (61,
#   'Eye for an Eye ',
#   'Drama|Thriller',
#   '1996',
#   '116260',
#   '17182',
#   'https://www.imdb.com/title/tt0116260',
#   'https://www.themoviedb.org/movie/17182',
#   '3.75',
#   ' '),
#  (62,
#   "Mr. Holland's Opus ",
#   'Drama',
#   '1995',
#   '113862',
#   '2054',
#   'https://www.imdb.com/title/tt0113862',
#   'https://www.themoviedb.org/movie/2054',
#   '3.70625',
#   'music'),
#  (63,
#   "Don't Be a Menace to South Central While Drinking Your Juice in the Hood ",
#   'Comedy|Crime',
#   '1996',
#   '116126',
#   '10607',
#   'https://www.imdb.com/title/tt0116126',
#   'https://www.themoviedb.org/movie/10607',
#   '2.7142857142857144',
#   ' '),
#  (64,
#   'Two if by Sea ',
#   'Comedy|Romance',
#   '1996',
#   '118002',
#   '19760',
#   'https://www.imdb.com/title/tt0118002',
#   'https://www.themoviedb.org/movie/19760',
#   '2.2',
#   ' '),
#  (65,
#   'Bio-Dome ',
#   'Comedy',
#   '1996',
#   '115683',
#   '9536',
#   'https://www.imdb.com/title/tt0115683',
#   'https://www.themoviedb.org/movie/9536',
#   '2.532258064516129',
#   ' '),
#  (66,
#   'Lawnmower Man 2: Beyond Cyberspace ',
#   'Action|Sci-Fi|Thriller',
#   '1996',
#   '116839',
#   '11525',
#   'https://www.imdb.com/title/tt0116839',
#   'https://www.themoviedb.org/movie/11525',
#   '2.5',
#   ' '),
#  (68,
#   'French Twist (Gazon maudit) ',
#   'Comedy|Romance',
#   '1995',
#   '113149',
#   '4482',
#   'https://www.imdb.com/title/tt0113149',
#   'https://www.themoviedb.org/movie/4482',
#   '3.4',
#   ' '),
#  (69,
#   'Friday ',
#   'Comedy',
#   '1995',
#   '113118',
#   '10634',
#   'https://www.imdb.com/title/tt0113118',
#   'https://www.themoviedb.org/movie/10634',
#   '3.775',
#   ' '),
#  (70,
#   'From Dusk Till Dawn ',
#   'Action|Comedy|Horror|Thriller',
#   '1996',
#   '116367',
#   '755',
#   'https://www.imdb.com/title/tt0116367',
#   'https://www.themoviedb.org/movie/755',
#   '3.5090909090909093',
#   ' '),
#  (71,
#   'Fair Game ',
#   'Action',
#   '1995',
#   '113010',
#   '11859',
#   'https://www.imdb.com/title/tt0113010',
#   'https://www.themoviedb.org/movie/11859',
#   '1.7',
#   ' '),
#  (72,
#   'Kicking and Screaming ',
#   'Comedy|Drama',
#   '1995',
#   '113537',
#   '28387',
#   'https://www.imdb.com/title/tt0113537',
#   'https://www.themoviedb.org/movie/28387',
#   '3.2142857142857144',
#   ' '),
#  (73,
#   'Misérables Les ',
#   'Drama|War',
#   '1995',
#   '113828',
#   '48750',
#   'https://www.imdb.com/title/tt0113828',
#   'https://www.themoviedb.org/movie/48750',
#   '3.4615384615384617',
#   ' '),
#  (74,
#   'Bed of Roses ',
#   'Drama|Romance',
#   '1996',
#   '115644',
#   '20927',
#   'https://www.imdb.com/title/tt0115644',
#   'https://www.themoviedb.org/movie/20927',
#   '4.0',
#   ' '),
#  (75,
#   'Big Bully ',
#   'Comedy|Drama',
#   '1996',
#   '115676',
#   '36929',
#   'https://www.imdb.com/title/tt0115676',
#   'https://www.themoviedb.org/movie/36929',
#   '2.2',
#   ' '),
#  (76,
#   'Screamers ',
#   'Action|Sci-Fi|Thriller',
#   '1995',
#   '114367',
#   '9102',
#   'https://www.imdb.com/title/tt0114367',
#   'https://www.themoviedb.org/movie/9102',
#   '3.4',
#   ' '),
#  (77,
#   'Nico Icon ',
#   'Documentary',
#   '1995',
#   '113973',
#   '124626',
#   'https://www.imdb.com/title/tt0113973',
#   'https://www.themoviedb.org/movie/124626',
#   '4.0',
#   ' '),
#  (78,
#   'Crossing Guard The ',
#   'Action|Crime|Drama|Thriller',
#   '1995',
#   '112744',
#   '27526',
#   'https://www.imdb.com/title/tt0112744',
#   'https://www.themoviedb.org/movie/27526',
#   '3.3333333333333335',
#   ' '),
#  (79,
#   'Juror The ',
#   'Drama|Thriller',
#   '1996',
#   '116731',
#   '9623',
#   'https://www.imdb.com/title/tt0116731',
#   'https://www.themoviedb.org/movie/9623',
#   '2.764705882352941',
#   ' '),
#  (80,
#   'White Balloon The (Badkonake sefid) ',
#   'Children|Drama',
#   '1995',
#   '112445',
#   '46785',
#   'https://www.imdb.com/title/tt0112445',
#   'https://www.themoviedb.org/movie/46785',
#   '4.0',
#   ' '),
#  (81,
#   "Things to Do in Denver When You're Dead ",
#   'Crime|Drama|Romance',
#   '1995',
#   '114660',
#   '400',
#   'https://www.imdb.com/title/tt0114660',
#   'https://www.themoviedb.org/movie/400',
#   '3.107142857142857',
#   ' '),
#  (82,
#   "Antonia's Line (Antonia) ",
#   'Comedy|Drama',
#   '1995',
#   '112379',
#   '880',
#   'https://www.imdb.com/title/tt0112379',
#   'https://www.themoviedb.org/movie/880',
#   '3.875',
#   ' '),
#  (83,
#   'Once Upon a Time... When We Were Colored ',
#   'Drama|Romance',
#   '1995',
#   '114039',
#   '146599',
#   'https://www.imdb.com/title/tt0114039',
#   'https://www.themoviedb.org/movie/146599',
#   '3.0',
#   ' '),
#  (85,
#   'Angels and Insects ',
#   'Drama|Romance',
#   '1995',
#   '112365',
#   '8447',
#   'https://www.imdb.com/title/tt0112365',
#   'https://www.themoviedb.org/movie/8447',
#   '3.857142857142857',
#   ' '),
#  (86,
#   'White Squall ',
#   'Action|Adventure|Drama',
#   '1996',
#   '118158',
#   '10534',
#   'https://www.imdb.com/title/tt0118158',
#   'https://www.themoviedb.org/movie/10534',
#   '3.966666666666667',
#   ' '),
#  (87,
#   'Dunston Checks In ',
#   'Children|Comedy',
#   '1996',
#   '116151',
#   '17414',
#   'https://www.imdb.com/title/tt0116151',
#   'https://www.themoviedb.org/movie/17414',
#   '2.5',
#   ' '),
#  (88,
#   'Black Sheep ',
#   'Comedy',
#   '1996',
#   '115697',
#   '13997',
#   'https://www.imdb.com/title/tt0115697',
#   'https://www.themoviedb.org/movie/13997',
#   '3.15625',
#   ' '),
#  (89,
#   'Nick of Time ',
#   'Action|Thriller',
#   '1995',
#   '113972',
#   '2086',
#   'https://www.imdb.com/title/tt0113972',
#   'https://www.themoviedb.org/movie/2086',
#   '3.25',
#   ' '),
#  (92,
#   'Mary Reilly ',
#   'Drama|Horror|Thriller',
#   '1996',
#   '117002',
#   '9095',
#   'https://www.imdb.com/title/tt0117002',
#   'https://www.themoviedb.org/movie/9095',
#   '2.625',
#   'Jekyll and Hyde'),
#  (93,
#   'Vampire in Brooklyn ',
#   'Comedy|Horror|Romance',
#   '1995',
#   '114825',
#   '12158',
#   'https://www.imdb.com/title/tt0114825',
#   'https://www.themoviedb.org/movie/12158',
#   '2.8333333333333335',
#   ' '),
#  (94,
#   'Beautiful Girls ',
#   'Comedy|Drama|Romance',
#   '1996',
#   '115639',
#   '9283',
#   'https://www.imdb.com/title/tt0115639',
#   'https://www.themoviedb.org/movie/9283',
#   '3.95',
#   ' '),
#  (95,
#   'Broken Arrow ',
#   'Action|Adventure|Thriller',
#   '1996',
#   '115759',
#   '9208',
#   'https://www.imdb.com/title/tt0115759',
#   'https://www.themoviedb.org/movie/9208',
#   '3.0238095238095237',
#   ' '),
#  (96,
#   'In the Bleak Midwinter ',
#   'Comedy|Drama',
#   '1995',
#   '113403',
#   '40154',
#   'https://www.imdb.com/title/tt0113403',
#   'https://www.themoviedb.org/movie/40154',
#   '3.5',
#   'theater'),
#  (99,
#   'Heidi Fleiss: Hollywood Madam ',
#   'Documentary',
#   '1995',
#   '113283',
#   '63076',
#   'https://www.imdb.com/title/tt0113283',
#   'https://www.themoviedb.org/movie/63076',
#   '5.0',
#   ' '),
#  (100,
#   'City Hall ',
#   'Drama|Thriller',
#   '1996',
#   '115907',
#   '11062',
#   'https://www.imdb.com/title/tt0115907',
#   'https://www.themoviedb.org/movie/11062',
#   '2.7857142857142856',
#   ' '),
#  (101,
#   'Bottle Rocket ',
#   'Adventure|Comedy|Crime|Romance',
#   '1996',
#   '115734',
#   '13685',
#   'https://www.imdb.com/title/tt0115734',
#   'https://www.themoviedb.org/movie/13685',
#   '3.782608695652174',
#   'quirky off-beat comedy crime'),
#  (102,
#   'Mr. Wrong ',
#   'Comedy',
#   '1996',
#   '117102',
#   '47475',
#   'https://www.imdb.com/title/tt0117102',
#   'https://www.themoviedb.org/movie/47475',
#   '2.4',
#   ' '),
#  (103,
#   'Unforgettable ',
#   'Mystery|Sci-Fi|Thriller',
#   '1996',
#   '118040',
#   '2045',
#   'https://www.imdb.com/title/tt0118040',
#   'https://www.themoviedb.org/movie/2045',
#   '3.0',
#   ' '),
#  (104,
#   'Happy Gilmore ',
#   'Comedy',
#   '1996',
#   '116483',
#   '9614',
#   'https://www.imdb.com/title/tt0116483',
#   'https://www.themoviedb.org/movie/9614',
#   '3.4393939393939394',
#   'test tag Adam Sandler golf'),
#  (105,
#   'Bridges of Madison County The ',
#   'Drama|Romance',
#   '1995',
#   '112579',
#   '688',
#   'https://www.imdb.com/title/tt0112579',
#   'https://www.themoviedb.org/movie/688',
#   '3.282608695652174',
#   ' '),
#  (106,
#   'Nobody Loves Me (Keiner liebt mich) ',
#   'Comedy|Drama',
#   '1994',
#   '110251',
#   '11907',
#   'https://www.imdb.com/title/tt0110251',
#   'https://www.themoviedb.org/movie/11907',
#   '4.0',
#   ' '),
#  (107,
#   'Muppet Treasure Island ',
#   'Adventure|Children|Comedy|Musical',
#   '1996',
#   '117110',
#   '10874',
#   'https://www.imdb.com/title/tt0117110',
#   'https://www.themoviedb.org/movie/10874',
#   '3.326923076923077',
#   'muppets'),
#  (108,
#   'Catwalk ',
#   'Documentary',
#   '1996',
#   '112646',
#   '89333',
#   'https://www.imdb.com/title/tt0112646',
#   'https://www.themoviedb.org/movie/89333',
#   '4.0',
#   ' '),
#  (110,
#   'Braveheart ',
#   'Action|Drama|War',
#   '1995',
#   '112573',
#   '197',
#   'https://www.imdb.com/title/tt0112573',
#   'https://www.themoviedb.org/movie/197',
#   '4.031645569620253',
#   'inspirational Oscar (Best Cinematography) epic mel gibson Scotland sword fight revenge beautiful scenery Medieval historical'),
#  (111,
#   'Taxi Driver ',
#   'Crime|Drama|Thriller',
#   '1976',
#   '75314',
#   '103',
#   'https://www.imdb.com/title/tt0075314',
#   'https://www.themoviedb.org/movie/103',
#   '4.105769230769231',
#   'assassination'),
#  (112,
#   'Rumble in the Bronx (Hont faan kui) ',
#   'Action|Adventure|Comedy|Crime',
#   '1995',
#   '113326',
#   '33542',
#   'https://www.imdb.com/title/tt0113326',
#   'https://www.themoviedb.org/movie/33542',
#   '3.5434782608695654',
#   ' '),
#  (113,
#   'Before and After ',
#   'Drama|Mystery',
#   '1996',
#   '115645',
#   '43566',
#   'https://www.imdb.com/title/tt0115645',
#   'https://www.themoviedb.org/movie/43566',
#   '3.3333333333333335',
#   ' '),
#  (116,
#   'Anne Frank Remembered ',
#   'Documentary',
#   '1995',
#   '112373',
#   '51352',
#   'https://www.imdb.com/title/tt0112373',
#   'https://www.themoviedb.org/movie/51352',
#   '3.9',
#   'Holocaust'),
#  (117,
#   "Young Poisoner's Handbook The ",
#   'Crime|Drama',
#   '1995',
#   '115033',
#   '16934',
#   'https://www.imdb.com/title/tt0115033',
#   'https://www.themoviedb.org/movie/16934',
#   '3.0',
#   ' '),
#  (118,
#   'If Lucy Fell ',
#   'Comedy|Romance',
#   '1996',
#   '116606',
#   '10324',
#   'https://www.imdb.com/title/tt0116606',
#   'https://www.themoviedb.org/movie/10324',
#   '2.5',
#   ' '),
#  (119,
#   'Steal Big Steal Little ',
#   'Comedy',
#   '1995',
#   '114536',
#   '78406',
#   'https://www.imdb.com/title/tt0114536',
#   'https://www.themoviedb.org/movie/78406',
#   '3.0',
#   ' '),
#  (121,
#   'Boys of St. Vincent The ',
#   'Drama',
#   '1992',
#   '106473',
#   '32119',
#   'https://www.imdb.com/title/tt0106473',
#   'https://www.themoviedb.org/movie/32119',
#   '4.0',
#   ' '),
#  (122,
#   'Boomerang ',
#   'Comedy|Romance',
#   '1992',
#   '103859',
#   '11066',
#   'https://www.imdb.com/title/tt0103859',
#   'https://www.themoviedb.org/movie/11066',
#   '2.65625',
#   'dating'),
#  (123,
#   'Chungking Express (Chung Hing sam lam) ',
#   'Drama|Mystery|Romance',
#   '1994',
#   '109424',
#   '11104',
#   'https://www.imdb.com/title/tt0109424',
#   'https://www.themoviedb.org/movie/11104',
#   '4.375',
#   ' '),
#  (125,
#   'Flirting With Disaster ',
#   'Comedy',
#   '1996',
#   '116324',
#   '2074',
#   'https://www.imdb.com/title/tt0116324',
#   'https://www.themoviedb.org/movie/2074',
#   '3.5833333333333335',
#   ' '),
#  (126,
#   'NeverEnding Story III The ',
#   'Adventure|Children|Fantasy',
#   '1994',
#   '110647',
#   '27793',
#   'https://www.imdb.com/title/tt0110647',
#   'https://www.themoviedb.org/movie/27793',
#   '2.0',
#   ' '),
#  (128,
#   "Jupiter's Wife ",
#   'Documentary',
#   '1994',
#   '110217',
#   '290157',
#   'https://www.imdb.com/title/tt0110217',
#   'https://www.themoviedb.org/movie/290157',
#   '3.0',
#   ' '),
#  (129,
#   'Pie in the Sky ',
#   'Comedy|Romance',
#   '1996',
#   '114131',
#   '110972',
#   'https://www.imdb.com/title/tt0114131',
#   'https://www.themoviedb.org/movie/110972',
#   '2.0',
#   ' '),
#  (132,
#   'Jade ',
#   'Thriller',
#   '1995',
#   '113451',
#   '11863',
#   'https://www.imdb.com/title/tt0113451',
#   'https://www.themoviedb.org/movie/11863',
#   '2.8333333333333335',
#   ' '),
#  (135,
#   'Down Periscope ',
#   'Comedy',
#   '1996',
#   '116130',
#   '9101',
#   'https://www.imdb.com/title/tt0116130',
#   'https://www.themoviedb.org/movie/9101',
#   '2.9516129032258065',
#   ' '),
#  (137,
#   'Man of the Year ',
#   'Documentary',
#   '1995',
#   '113756',
#   '5757',
#   'https://www.imdb.com/title/tt0113756',
#   'https://www.themoviedb.org/movie/5757',
#   '3.0',
#   ' '),
#  (140,
#   'Up Close and Personal ',
#   'Drama|Romance',
#   '1996',
#   '118055',
#   '9302',
#   'https://www.imdb.com/title/tt0118055',
#   'https://www.themoviedb.org/movie/9302',
#   '3.5',
#   'journalism'),
#  (141,
#   'Birdcage The ',
#   'Comedy',
#   '1996',
#   '115685',
#   '11000',
#   'https://www.imdb.com/title/tt0115685',
#   'https://www.themoviedb.org/movie/11000',
#   '3.494186046511628',
#   ' '),
#  (144,
#   'Brothers McMullen The ',
#   'Comedy',
#   '1995',
#   '112585',
#   '16388',
#   'https://www.imdb.com/title/tt0112585',
#   'https://www.themoviedb.org/movie/16388',
#   '3.3333333333333335',
#   ' '),
#  (145,
#   'Bad Boys ',
#   'Action|Comedy|Crime|Drama|Thriller',
#   '1995',
#   '112442',
#   '9737',
#   'https://www.imdb.com/title/tt0112442',
#   'https://www.themoviedb.org/movie/9737',
#   '3.2450980392156863',
#   ' '),
#  (146,
#   'Amazing Panda Adventure The ',
#   'Adventure|Children',
#   '1995',
#   '112342',
#   '30765',
#   'https://www.imdb.com/title/tt0112342',
#   'https://www.themoviedb.org/movie/30765',
#   '3.3333333333333335',
#   ' '),
#  (147,
#   'Basketball Diaries The ',
#   'Drama',
#   '1995',
#   '112461',
#   '10474',
#   'https://www.imdb.com/title/tt0112461',
#   'https://www.themoviedb.org/movie/10474',
#   '3.466666666666667',
#   'Mark Wahlberg heroin addiction Leonardo DiCaprio'),
#  (148,
#   'Awfully Big Adventure An ',
#   'Drama',
#   '1995',
#   '112427',
#   '22279',
#   'https://www.imdb.com/title/tt0112427',
#   'https://www.themoviedb.org/movie/22279',
#   '5.0',
#   ' '),
#  (149,
#   'Amateur ',
#   'Crime|Drama|Thriller',
#   '1994',
#   '109093',
#   '30157',
#   'https://www.imdb.com/title/tt0109093',
#   'https://www.themoviedb.org/movie/30157',
#   '2.0',
#   ' '),
#  (150,
#   'Apollo 13 ',
#   'Adventure|Drama|IMAX',
#   '1995',
#   '112384',
#   '568',
#   'https://www.imdb.com/title/tt0112384',
#   'https://www.themoviedb.org/movie/568',
#   '3.845771144278607',
#   'space NASA moon'),
#  (151,
#   'Rob Roy ',
#   'Action|Drama|Romance|War',
#   '1995',
#   '114287',
#   '11780',
#   'https://www.imdb.com/title/tt0114287',
#   'https://www.themoviedb.org/movie/11780',
#   '3.5454545454545454',
#   ' '),
#  (152,
#   'Addiction The ',
#   'Drama|Horror',
#   '1995',
#   '112288',
#   '34996',
#   'https://www.imdb.com/title/tt0112288',
#   'https://www.themoviedb.org/movie/34996',
#   '1.5',
#   ' '),
#  (153,
#   'Batman Forever ',
#   'Action|Adventure|Comedy|Crime',
#   '1995',
#   '112462',
#   '414',
#   'https://www.imdb.com/title/tt0112462',
#   'https://www.themoviedb.org/movie/414',
#   '2.9160583941605838',
#   'superhero'),
#  (154,
#   'Beauty of the Day (Belle de jour) ',
#   'Drama',
#   '1967',
#   '61395',
#   '649',
#   'https://www.imdb.com/title/tt0061395',
#   'https://www.themoviedb.org/movie/649',
#   '3.875',
#   ' '),
#  (155,
#   'Beyond Rangoon ',
#   'Adventure|Drama|War',
#   '1995',
#   '112495',
#   '1873',
#   'https://www.imdb.com/title/tt0112495',
#   'https://www.themoviedb.org/movie/1873',
#   '2.4166666666666665',
#   ' '),
#  (156,
#   'Blue in the Face ',
#   'Comedy|Drama',
#   '1995',
#   '112541',
#   '5894',
#   'https://www.imdb.com/title/tt0112541',
#   'https://www.themoviedb.org/movie/5894',
#   '3.3333333333333335',
#   ' '),
#  (157,
#   'Canadian Bacon ',
#   'Comedy|War',
#   '1995',
#   '109370',
#   '1775',
#   'https://www.imdb.com/title/tt0109370',
#   'https://www.themoviedb.org/movie/1775',
#   '2.8636363636363638',
#   ' '),
#  (158,
#   'Casper ',
#   'Adventure|Children',
#   '1995',
#   '112642',
#   '8839',
#   'https://www.imdb.com/title/tt0112642',
#   'https://www.themoviedb.org/movie/8839',
#   '2.806451612903226',
#   ' '),
#  (159,
#   'Clockers ',
#   'Crime|Drama|Mystery',
#   '1995',
#   '112688',
#   '20649',
#   'https://www.imdb.com/title/tt0112688',
#   'https://www.themoviedb.org/movie/20649',
#   '2.892857142857143',
#   ' '),
#  (160,
#   'Congo ',
#   'Action|Adventure|Mystery|Sci-Fi',
#   '1995',
#   '112715',
#   '10329',
#   'https://www.imdb.com/title/tt0112715',
#   'https://www.themoviedb.org/movie/10329',
#   '2.8771929824561404',
#   'Michael Crichton'),
#  (161,
#   'Crimson Tide ',
#   'Drama|Thriller|War',
#   '1995',
#   '112740',
#   '8963',
#   'https://www.imdb.com/title/tt0112740',
#   'https://www.themoviedb.org/movie/8963',
#   '3.6359223300970873',
#   'submarine'),
#  (162,
#   'Crumb ',
#   'Documentary',
#   '1994',
#   '109508',
#   '26564',
#   'https://www.imdb.com/title/tt0109508',
#   'https://www.themoviedb.org/movie/26564',
#   '4.205882352941177',
#   'In Netflix queue'),
#  (163,
#   'Desperado ',
#   'Action|Romance|Western',
#   '1995',
#   '112851',
#   '8068',
#   'https://www.imdb.com/title/tt0112851',
#   'https://www.themoviedb.org/movie/8068',
#   '3.5606060606060606',
#   ' '),
#  (164,
#   'Devil in a Blue Dress ',
#   'Crime|Film-Noir|Mystery|Thriller',
#   '1995',
#   '112857',
#   '8512',
#   'https://www.imdb.com/title/tt0112857',
#   'https://www.themoviedb.org/movie/8512',
#   '3.3214285714285716',
#   ' '),
#  (165,
#   'Die Hard: With a Vengeance ',
#   'Action|Crime|Thriller',
#   '1995',
#   '112864',
#   '1572',
#   'https://www.imdb.com/title/tt0112864',
#   'https://www.themoviedb.org/movie/1572',
#   '3.5555555555555554',
#   ' '),
#  (166,
#   'Doom Generation The ',
#   'Comedy|Crime|Drama',
#   '1995',
#   '112887',
#   '13552',
#   'https://www.imdb.com/title/tt0112887',
#   'https://www.themoviedb.org/movie/13552',
#   '2.8333333333333335',
#   ' '),
#  (168,
#   'First Knight ',
#   'Action|Drama|Romance',
#   '1995',
#   '113071',
#   '6520',
#   'https://www.imdb.com/title/tt0113071',
#   'https://www.themoviedb.org/movie/6520',
#   '3.0833333333333335',
#   ' '),
#  (169,
#   'Free Willy 2: The Adventure Home ',
#   'Adventure|Children|Drama',
#   '1995',
#   '113114',
#   '9073',
#   'https://www.imdb.com/title/tt0113114',
#   'https://www.themoviedb.org/movie/9073',
#   '2.4',
#   ' '),
#  (170,
#   'Hackers ',
#   'Action|Adventure|Crime|Thriller',
#   '1995',
#   '113243',
#   '10428',
#   'https://www.imdb.com/title/tt0113243',
#   'https://www.themoviedb.org/movie/10428',
#   '3.2285714285714286',
#   ' '),
#  (171,
#   'Jeffrey ',
#   'Comedy|Drama',
#   '1995',
#   '113464',
#   '17447',
#   'https://www.imdb.com/title/tt0113464',
#   'https://www.themoviedb.org/movie/17447',
#   '3.8333333333333335',
#   ' '),
#  (172,
#   'Johnny Mnemonic ',
#   'Action|Sci-Fi|Thriller',
#   '1995',
#   '113481',
#   '9886',
#   'https://www.imdb.com/title/tt0113481',
#   'https://www.themoviedb.org/movie/9886',
#   '2.6792452830188678',
#   ' '),
#  (173,
#   'Judge Dredd ',
#   'Action|Crime|Sci-Fi',
#   '1995',
#   '113492',
#   '9482',
#   'https://www.imdb.com/title/tt0113492',
#   'https://www.themoviedb.org/movie/9482',
#   '2.6693548387096775',
#   ' '),
#  (174,
#   'Jury Duty ',
#   'Comedy',
#   '1995',
#   '113500',
#   '19326',
#   'https://www.imdb.com/title/tt0113500',
#   'https://www.themoviedb.org/movie/19326',
#   '2.7',
#   ' '),
#  (175,
#   'Kids ',
#   'Drama',
#   '1995',
#   '113540',
#   '9344',
#   'https://www.imdb.com/title/tt0113540',
#   'https://www.themoviedb.org/movie/9344',
#   '3.975',
#   'Nudity (Full Frontal) New York City controversial'),
#  (176,
#   'Living in Oblivion ',
#   'Comedy',
#   '1995',
#   '113677',
#   '9071',
#   'https://www.imdb.com/title/tt0113677',
#   'https://www.themoviedb.org/movie/9071',
#   '4.3076923076923075',
#   ' '),
#  (177,
#   'Lord of Illusions ',
#   'Horror',
#   '1995',
#   '113690',
#   '8973',
#   'https://www.imdb.com/title/tt0113690',
#   'https://www.themoviedb.org/movie/8973',
#   '2.75',
#   ' '),
#  (178,
#   'Love & Human Remains ',
#   'Comedy|Drama',
#   '1993',
#   '107447',
#   '15730',
#   'https://www.imdb.com/title/tt0107447',
#   'https://www.themoviedb.org/movie/15730',
#   '1.0',
#   ' '),
#  (179,
#   'Mad Love ',
#   'Drama|Romance',
#   '1995',
#   '113729',
#   '47608',
#   'https://www.imdb.com/title/tt0113729',
#   'https://www.themoviedb.org/movie/47608',
#   '1.5',
#   ' '),
#  (180,
#   'Mallrats ',
#   'Comedy|Romance',
#   '1995',
#   '113749',
#   '2293',
#   'https://www.imdb.com/title/tt0113749',
#   'https://www.themoviedb.org/movie/2293',
#   '3.4027777777777777',
#   ' '),
#  (181,
#   'Mighty Morphin Power Rangers: The Movie ',
#   'Action|Children',
#   '1995',
#   '113820',
#   '9070',
#   'https://www.imdb.com/title/tt0113820',
#   'https://www.themoviedb.org/movie/9070',
#   '2.264705882352941',
#   ' '),
#  (183,
#   'Mute Witness ',
#   'Comedy|Horror|Thriller',
#   '1994',
#   '110604',
#   '48787',
#   'https://www.imdb.com/title/tt0110604',
#   'https://www.themoviedb.org/movie/48787',
#   '3.5',
#   ' '),
#  (184,
#   'Nadja ',
#   'Drama',
#   '1994',
#   '110620',
#   '34574',
#   'https://www.imdb.com/title/tt0110620',
#   'https://www.themoviedb.org/movie/34574',
#   '3.5',
#   ' '),
#  (185,
#   'Net The ',
#   'Action|Crime|Thriller',
#   '1995',
#   '113957',
#   '1642',
#   'https://www.imdb.com/title/tt0113957',
#   'https://www.themoviedb.org/movie/1642',
#   '3.0401785714285716',
#   'computers'),
#  (186,
#   'Nine Months ',
#   'Comedy|Romance',
#   '1995',
#   '113986',
#   '11472',
#   'https://www.imdb.com/title/tt0113986',
#   'https://www.themoviedb.org/movie/11472',
#   '2.8229166666666665',
#   ' '),
#  (187,
#   'Party Girl ',
#   'Comedy',
#   '1995',
#   '114095',
#   '36196',
#   'https://www.imdb.com/title/tt0114095',
#   'https://www.themoviedb.org/movie/36196',
#   '4.125',
#   ' '),
#  (188,
#   'Prophecy The ',
#   'Fantasy|Horror|Mystery',
#   '1995',
#   '114194',
#   '11980',
#   'https://www.imdb.com/title/tt0114194',
#   'https://www.themoviedb.org/movie/11980',
#   '3.4583333333333335',
#   ' '),
#  (189,
#   'Reckless ',
#   'Comedy|Fantasy',
#   '1995',
#   '114241',
#   '58372',
#   'https://www.imdb.com/title/tt0114241',
#   'https://www.themoviedb.org/movie/58372',
#   '3.0',
#   ' '),
#  (190,
#   'Safe ',
#   'Thriller',
#   '1995',
#   '114323',
#   '32646',
#   'https://www.imdb.com/title/tt0114323',
#   'https://www.themoviedb.org/movie/32646',
#   '2.8',
#   ' '),
#  (191,
#   'Scarlet Letter The ',
#   'Drama|Romance',
#   '1995',
#   '114345',
#   '10533',
#   'https://www.imdb.com/title/tt0114345',
#   'https://www.themoviedb.org/movie/10533',
#   '2.4166666666666665',
#   ' '),
#  (193,
#   'Showgirls ',
#   'Drama',
#   '1995',
#   '114436',
#   '10802',
#   'https://www.imdb.com/title/tt0114436',
#   'https://www.themoviedb.org/movie/10802',
#   '2.4714285714285715',
#   ' '),
#  (194,
#   'Smoke ',
#   'Comedy|Drama',
#   '1995',
#   '114478',
#   '10149',
#   'https://www.imdb.com/title/tt0114478',
#   'https://www.themoviedb.org/movie/10149',
#   '3.6666666666666665',
#   ' '),
#  (195,
#   'Something to Talk About ',
#   'Comedy|Drama|Romance',
#   '1995',
#   '114496',
#   '18402',
#   'https://www.imdb.com/title/tt0114496',
#   'https://www.themoviedb.org/movie/18402',
#   '3.1',
#   ' '),
#  (196,
#   'Species ',
#   'Horror|Sci-Fi',
#   '1995',
#   '114508',
#   '9348',
#   'https://www.imdb.com/title/tt0114508',
#   'https://www.themoviedb.org/movie/9348',
#   '2.6666666666666665',
#   ' '),
#  (198,
#   'Strange Days ',
#   'Action|Crime|Drama|Mystery|Sci-Fi|Thriller',
#   '1995',
#   '114558',
#   '281',
#   'https://www.imdb.com/title/tt0114558',
#   'https://www.themoviedb.org/movie/281',
#   '3.25',
#   ' '),
#  (199,
#   'Umbrellas of Cherbourg The (Parapluies de Cherbourg Les) ',
#   'Drama|Musical|Romance',
#   '1964',
#   '58450',
#   '5967',
#   'https://www.imdb.com/title/tt0058450',
#   'https://www.themoviedb.org/movie/5967',
#   '4.125',
#   'Made me cry'),
#  (201,
#   'Three Wishes ',
#   'Drama|Fantasy',
#   '1995',
#   '114663',
#   '47939',
#   'https://www.imdb.com/title/tt0114663',
#   'https://www.themoviedb.org/movie/47939',
#   '3.0',
#   ' '),
#  (202,
#   'Total Eclipse ',
#   'Drama|Romance',
#   '1995',
#   '114702',
#   '36834',
#   'https://www.imdb.com/title/tt0114702',
#   'https://www.themoviedb.org/movie/36834',
#   '3.0',
#   ' '),
#  (203,
#   'To Wong Foo Thanks for Everything! Julie Newmar ',
#   'Comedy',
#   '1995',
#   '114682',
#   '9090',
#   'https://www.imdb.com/title/tt0114682',
#   'https://www.themoviedb.org/movie/9090',
#   '3.4318181818181817',
#   ' '),
#  (204,
#   'Under Siege 2: Dark Territory ',
#   'Action',
#   '1995',
#   '114781',
#   '3512',
#   'https://www.imdb.com/title/tt0114781',
#   'https://www.themoviedb.org/movie/3512',
#   '2.716666666666667',
#   ' '),
#  (205,
#   'Unstrung Heroes ',
#   'Comedy|Drama',
#   '1995',
#   '114798',
#   '52856',
#   'https://www.imdb.com/title/tt0114798',
#   'https://www.themoviedb.org/movie/52856',
#   '3.1666666666666665',
#   ' '),
#  (206,
#   'Unzipped ',
#   'Documentary',
#   '1995',
#   '114805',
#   '77350',
#   'https://www.imdb.com/title/tt0114805',
#   'https://www.themoviedb.org/movie/77350',
#   '3.0',
#   ' '),
#  (207,
#   'Walk in the Clouds A ',
#   'Drama|Romance',
#   '1995',
#   '114887',
#   '9560',
#   'https://www.imdb.com/title/tt0114887',
#   'https://www.themoviedb.org/movie/9560',
#   '3.4285714285714284',
#   ' '),
#  (208,
#   'Waterworld ',
#   'Action|Adventure|Sci-Fi',
#   '1995',
#   '114898',
#   '9804',
#   'https://www.imdb.com/title/tt0114898',
#   'https://www.themoviedb.org/movie/9804',
#   '2.9130434782608696',
#   ' '),
#  (209,
#   "White Man's Burden ",
#   'Drama',
#   '1995',
#   '114928',
#   '31611',
#   'https://www.imdb.com/title/tt0114928',
#   'https://www.themoviedb.org/movie/31611',
#   '3.1666666666666665',
#   ' '),
#  (210,
#   'Wild Bill ',
#   'Western',
#   '1995',
#   '114938',
#   '65796',
#   'https://www.imdb.com/title/tt0114938',
#   'https://www.themoviedb.org/movie/65796',
#   '3.0',
#   ' '),
#  (211,
#   'Browning Version The ',
#   'Drama',
#   '1994',
#   '109340',
#   '49805',
#   'https://www.imdb.com/title/tt0109340',
#   'https://www.themoviedb.org/movie/49805',
#   '3.5',
#   ' '),
#  (212,
#   'Bushwhacked ',
#   'Adventure|Comedy|Crime|Mystery',
#   '1995',
#   '112602',
#   '26258',
#   'https://www.imdb.com/title/tt0112602',
#   'https://www.themoviedb.org/movie/26258',
#   '3.0',
#   ' '),
#  (213,
#   'Burnt by the Sun (Utomlyonnye solntsem) ',
#   'Drama',
#   '1994',
#   '111579',
#   '50797',
#   'https://www.imdb.com/title/tt0111579',
#   'https://www.themoviedb.org/movie/50797',
#   '3.8333333333333335',
#   ' '),
#  (214,
#   'Before the Rain (Pred dozhdot) ',
#   'Drama|War',
#   '1994',
#   '110882',
#   '19155',
#   'https://www.imdb.com/title/tt0110882',
#   'https://www.themoviedb.org/movie/19155',
#   '4.0',
#   ' '),
#  (215,
#   'Before Sunrise ',
#   'Drama|Romance',
#   '1995',
#   '112471',
#   '76',
#   'https://www.imdb.com/title/tt0112471',
#   'https://www.themoviedb.org/movie/76',
#   '4.041666666666667',
#   'generation X'),
#  (216,
#   'Billy Madison ',
#   'Comedy',
#   '1995',
#   '112508',
#   '11017',
#   'https://www.imdb.com/title/tt0112508',
#   'https://www.themoviedb.org/movie/11017',
#   '3.326530612244898',
#   'Adam Sandler stop looking at me swan school'),
#  (217,
#   'Babysitter The ',
#   'Drama|Thriller',
#   '1995',
#   '112438',
#   '37141',
#   'https://www.imdb.com/title/tt0112438',
#   'https://www.themoviedb.org/movie/37141',
#   '2.3333333333333335',
#   ' '),
#  (218,
#   'Boys on the Side ',
#   'Comedy|Drama',
#   '1995',
#   '112571',
#   '9382',
#   'https://www.imdb.com/title/tt0112571',
#   'https://www.themoviedb.org/movie/9382',
#   '3.4285714285714284',
#   ' '),
#  (219,
#   'Cure The ',
#   'Drama',
#   '1995',
#   '112757',
#   '6715',
#   'https://www.imdb.com/title/tt0112757',
#   'https://www.themoviedb.org/movie/6715',
#   '3.0',
#   ' '),
#  (220,
#   'Castle Freak ',
#   'Horror',
#   '1995',
#   '112643',
#   '18256',
#   'https://www.imdb.com/title/tt0112643',
#   'https://www.themoviedb.org/movie/18256',
#   '3.0',
#   ' '),
#  (222,
#   'Circle of Friends ',
#   'Drama|Romance',
#   '1995',
#   '112679',
#   '22625',
#   'https://www.imdb.com/title/tt0112679',
#   'https://www.themoviedb.org/movie/22625',
#   '3.75',
#   'Ireland'),
#  (223,
#   'Clerks ',
#   'Comedy',
#   '1994',
#   '109445',
#   '2292',
#   'https://www.imdb.com/title/tt0109445',
#   'https://www.themoviedb.org/movie/2292',
#   '3.855769230769231',
#   'quirky witty hilarious independent film cynical generation X'),
#  (224,
#   'Don Juan DeMarco ',
#   'Comedy|Drama|Romance',
#   '1995',
#   '112883',
#   '1909',
#   'https://www.imdb.com/title/tt0112883',
#   'https://www.themoviedb.org/movie/1909',
#   '3.6125',
#   'mental illness psychology'),
#  (225,
#   'Disclosure ',
#   'Drama|Thriller',
#   '1994',
#   '109635',
#   '8984',
#   'https://www.imdb.com/title/tt0109635',
#   'https://www.themoviedb.org/movie/8984',
#   '3.5384615384615383',
#   ' '),
#  (227,
#   'Drop Zone ',
#   'Action|Thriller',
#   '1994',
#   '109676',
#   '4954',
#   'https://www.imdb.com/title/tt0109676',
#   'https://www.themoviedb.org/movie/4954',
#   '2.8636363636363638',
#   ' '),
#  (228,
#   'Destiny Turns on the Radio ',
#   'Comedy',
#   '1995',
#   '112854',
#   '62488',
#   'https://www.imdb.com/title/tt0112854',
#   'https://www.themoviedb.org/movie/62488',
#   '2.3333333333333335',
#   ' '),
#  (229,
#   'Death and the Maiden ',
#   'Drama|Thriller',
#   '1994',
#   '109579',
#   '10531',
#   'https://www.imdb.com/title/tt0109579',
#   'https://www.themoviedb.org/movie/10531',
#   '3.4285714285714284',
#   ' '),
#  (230,
#   'Dolores Claiborne ',
#   'Drama|Thriller',
#   '1995',
#   '109642',
#   '11929',
#   'https://www.imdb.com/title/tt0109642',
#   'https://www.themoviedb.org/movie/11929',
#   '3.3958333333333335',
#   'Stephen King'),
#  (231,
#   'Dumb & Dumber (Dumb and Dumber) ',
#   'Adventure|Comedy',
#   '1994',
#   '109686',
#   '8467',
#   'https://www.imdb.com/title/tt0109686',
#   'https://www.themoviedb.org/movie/8467',
#   '3.0601503759398496',
#   ' '),
#  (232,
#   'Eat Drink Man Woman (Yin shi nan nu) ',
#   'Comedy|Drama|Romance',
#   '1994',
#   '111797',
#   '10451',
#   'https://www.imdb.com/title/tt0111797',
#   'https://www.themoviedb.org/movie/10451',
#   '3.892857142857143',
#   'In Netflix queue'),
#  (233,
#   'Exotica ',
#   'Drama',
#   '1994',
#   '109759',
#   '20156',
#   'https://www.imdb.com/title/tt0109759',
#   'https://www.themoviedb.org/movie/20156',
#   '3.5',
#   ' '),
#  (234,
#   'Exit to Eden ',
#   'Comedy',
#   '1994',
#   '109758',
#   '18395',
#   'https://www.imdb.com/title/tt0109758',
#   'https://www.themoviedb.org/movie/18395',
#   '2.588235294117647',
#   ' '),
#  (235,
#   'Ed Wood ',
#   'Comedy|Drama',
#   '1994',
#   '109707',
#   '522',
#   'https://www.imdb.com/title/tt0109707',
#   'https://www.themoviedb.org/movie/522',
#   '3.6785714285714284',
#   'movie business'),
#  (236,
#   'French Kiss ',
#   'Action|Comedy|Romance',
#   '1995',
#   '113117',
#   '397',
#   'https://www.imdb.com/title/tt0113117',
#   'https://www.themoviedb.org/movie/397',
#   '3.477777777777778',
#   ' '),
#  (237,
#   'Forget Paris ',
#   'Comedy|Romance',
#   '1995',
#   '113097',
#   '10525',
#   'https://www.imdb.com/title/tt0113097',
#   'https://www.themoviedb.org/movie/10525',
#   '3.340909090909091',
#   'France infertility basketball'),
#  (238,
#   'Far From Home: The Adventures of Yellow Dog ',
#   'Adventure|Children',
#   '1995',
#   '113028',
#   '27985',
#   'https://www.imdb.com/title/tt0113028',
#   'https://www.themoviedb.org/movie/27985',
#   '4.0',
#   ' '),
#  (239,
#   'Goofy Movie A ',
#   'Animation|Children|Comedy|Romance',
#   '1995',
#   '113198',
#   '15789',
#   'https://www.imdb.com/title/tt0113198',
#   'https://www.themoviedb.org/movie/15789',
#   '3.0',
#   ' '),
#  (240,
#   'Hideaway ',
#   'Thriller',
#   '1995',
#   '113303',
#   '27303',
#   'https://www.imdb.com/title/tt0113303',
#   'https://www.themoviedb.org/movie/27303',
#   '2.375',
#   ' '),
#  (241,
#   'Fluke ',
#   'Children|Drama',
#   '1995',
#   '113089',
#   '21183',
#   'https://www.imdb.com/title/tt0113089',
#   'https://www.themoviedb.org/movie/21183',
#   '4.0',
#   ' '),
#  (242,
#   'Farinelli: il castrato ',
#   'Drama|Musical',
#   '1994',
#   '109771',
#   '10954',
#   'https://www.imdb.com/title/tt0109771',
#   'https://www.themoviedb.org/movie/10954',
#   '3.6',
#   ' '),
#  (243,
#   'Gordy ',
#   'Children|Comedy|Fantasy',
#   '1995',
#   '113199',
#   '47867',
#   'https://www.imdb.com/title/tt0113199',
#   'https://www.themoviedb.org/movie/47867',
#   '3.0',
#   ' '),
#  (246,
#   'Hoop Dreams ',
#   'Documentary',
#   '1994',
#   '110057',
#   '14275',
#   'https://www.imdb.com/title/tt0110057',
#   'https://www.themoviedb.org/movie/14275',
#   '4.293103448275862',
#   'basketball'),
#  (247,
#   'Heavenly Creatures ',
#   'Crime|Drama',
#   '1994',
#   '110005',
#   '1024',
#   'https://www.imdb.com/title/tt0110005',
#   'https://www.themoviedb.org/movie/1024',
#   '3.9285714285714284',
#   'Australia'),
#  (248,
#   'Houseguest ',
#   'Comedy',
#   '1994',
#   '110066',
#   '17207',
#   'https://www.imdb.com/title/tt0110066',
#   'https://www.themoviedb.org/movie/17207',
#   '3.176470588235294',
#   'bad Sinbad'),
#  (249,
#   'Immortal Beloved ',
#   'Drama|Romance',
#   '1994',
#   '110116',
#   '13701',
#   'https://www.imdb.com/title/tt0110116',
#   'https://www.themoviedb.org/movie/13701',
#   '3.7222222222222223',
#   'Beethoven'),
#  (250,
#   'Heavyweights (Heavy Weights) ',
#   'Children|Comedy',
#   '1995',
#   '110006',
#   '14819',
#   'https://www.imdb.com/title/tt0110006',
#   'https://www.themoviedb.org/movie/14819',
#   '2.5',
#   ' '),
#  (251,
#   'Hunted The ',
#   'Action',
#   '1995',
#   '113360',
#   '32631',
#   'https://www.imdb.com/title/tt0113360',
#   'https://www.themoviedb.org/movie/32631',
#   '3.0',
#   ' '),
#  (252,
#   'I.Q. ',
#   'Comedy|Romance',
#   '1994',
#   '110099',
#   '11777',
#   'https://www.imdb.com/title/tt0110099',
#   'https://www.themoviedb.org/movie/11777',
#   '3.453488372093023',
#   'Einstein'),
#  (253,
#   'Interview with the Vampire: The Vampire Chronicles ',
#   'Drama|Horror',
#   '1994',
#   '110148',
#   '628',
#   'https://www.imdb.com/title/tt0110148',
#   'https://www.themoviedb.org/movie/628',
#   '3.458715596330275',
#   ' '),
#  (254,
#   'Jefferson in Paris ',
#   'Drama',
#   '1995',
#   '113463',
#   '87729',
#   'https://www.imdb.com/title/tt0113463',
#   'https://www.themoviedb.org/movie/87729',
#   '3.0',
#   ' '),
#  (255,
#   'Jerky Boys The ',
#   'Comedy',
#   '1995',
#   '110189',
#   '18713',
#   'https://www.imdb.com/title/tt0110189',
#   'https://www.themoviedb.org/movie/18713',
#   '2.0714285714285716',
#   ' '),
#  (256,
#   'Junior ',
#   'Comedy|Sci-Fi',
#   '1994',
#   '110216',
#   '6280',
#   'https://www.imdb.com/title/tt0110216',
#   'https://www.themoviedb.org/movie/6280',
#   '2.8285714285714287',
#   ' '),
#  (257,
#   'Just Cause ',
#   'Mystery|Thriller',
#   '1995',
#   '113501',
#   '9061',
#   'https://www.imdb.com/title/tt0113501',
#   'https://www.themoviedb.org/movie/9061',
#   '3.5',
#   'court'),
#  (258,
#   "Kid in King Arthur's Court A ",
#   'Adventure|Children|Comedy|Fantasy|Romance',
#   '1995',
#   '113538',
#   '37108',
#   'https://www.imdb.com/title/tt0113538',
#   'https://www.themoviedb.org/movie/37108',
#   '2.6',
#   ' '),
#  (259,
#   'Kiss of Death ',
#   'Crime|Drama|Thriller',
#   '1995',
#   '113552',
#   '6071',
#   'https://www.imdb.com/title/tt0113552',
#   'https://www.themoviedb.org/movie/6071',
#   '3.2',
#   ' '),
#  (260,
#   'Star Wars: Episode IV - A New Hope ',
#   'Action|Adventure|Sci-Fi',
#   '1977',
#   '76759',
#   '11',
#   'https://www.imdb.com/title/tt0076759',
#   'https://www.themoviedb.org/movie/11',
#   '4.231075697211155',
#   'space adventure Nerd engrossing adventure great soundtrack classic sci-fi sci-fi space epic action ROBOTS AND ANDROIDS space opera space EPIC space action Star Wars darth vader luke skywalker classic oldie but goodie'),
#  (261,
#   'Little Women ',
#   'Drama',
#   '1994',
#   '110367',
#   '9587',
#   'https://www.imdb.com/title/tt0110367',
#   'https://www.themoviedb.org/movie/9587',
#   '3.880952380952381',
#   'Louisa May Alcott'),
#  (262,
#   'Little Princess A ',
#   'Children|Drama',
#   '1995',
#   '113670',
#   '19101',
#   'https://www.imdb.com/title/tt0113670',
#   'https://www.themoviedb.org/movie/19101',
#   '3.9047619047619047',
#   'India Girl Power England'),
#  (263,
#   'Ladybird Ladybird ',
#   'Drama',
#   '1994',
#   '110296',
#   '49980',
#   'https://www.imdb.com/title/tt0110296',
#   'https://www.themoviedb.org/movie/49980',
#   '4.0',
#   ' '),
#  (265,
#   'Like Water for Chocolate (Como agua para chocolate) ',
#   'Drama|Fantasy|Romance',
#   '1992',
#   '103994',
#   '18183',
#   'https://www.imdb.com/title/tt0103994',
#   'https://www.themoviedb.org/movie/18183',
#   '3.9393939393939394',
#   ' '),
#  (266,
#   'Legends of the Fall ',
#   'Drama|Romance|War|Western',
#   '1994',
#   '110322',
#   '4476',
#   'https://www.imdb.com/title/tt0110322',
#   'https://www.themoviedb.org/movie/4476',
#   '3.3970588235294117',
#   ' '),
#  (267,
#   'Major Payne ',
#   'Comedy',
#   '1995',
#   '110443',
#   '11008',
#   'https://www.imdb.com/title/tt0110443',
#   'https://www.themoviedb.org/movie/11008',
#   '2.9411764705882355',
#   ' '),
#  (269,
#   'My Crazy Life (Mi vida loca) ',
#   'Drama',
#   '1993',
#   '107566',
#   '32325',
#   'https://www.imdb.com/title/tt0107566',
#   'https://www.themoviedb.org/movie/32325',
#   '3.0',
#   ' '),
#  (270,
#   'Love Affair ',
#   'Drama|Romance',
#   '1994',
#   '110391',
#   '43742',
#   'https://www.imdb.com/title/tt0110391',
#   'https://www.themoviedb.org/movie/43742',
#   '3.4',
#   ' '),
#  (271,
#   'Losing Isaiah ',
#   'Drama',
#   '1995',
#   '113691',
#   '28313',
#   'https://www.imdb.com/title/tt0113691',
#   'https://www.themoviedb.org/movie/28313',
#   '3.5',
#   ' '),
#  (272,
#   'Madness of King George The ',
#   'Comedy|Drama',
#   '1994',
#   '110428',
#   '11318',
#   'https://www.imdb.com/title/tt0110428',
#   'https://www.themoviedb.org/movie/11318',
#   '3.7580645161290325',
#   'mental illness England'),
#  (273,
#   "Mary Shelley's Frankenstein (Frankenstein) ",
#   'Drama|Horror|Sci-Fi',
#   '1994',
#   '109836',
#   '3036',
#   'https://www.imdb.com/title/tt0109836',
#   'https://www.themoviedb.org/movie/3036',
#   '2.9464285714285716',
#   'gothic'),
#  (274,
#   'Man of the House ',
#   'Comedy',
#   '1995',
#   '113755',
#   '40490',
#   'https://www.imdb.com/title/tt0113755',
#   'https://www.themoviedb.org/movie/40490',
#   '2.9285714285714284',
#   ' '),
#  (275,
#   'Mixed Nuts ',
#   'Comedy',
#   '1994',
#   '110538',
#   '24070',
#   'https://www.imdb.com/title/tt0110538',
#   'https://www.themoviedb.org/movie/24070',
#   '2.0',
#   ' '),
#  (276,
#   'Milk Money ',
#   'Comedy|Romance',
#   '1994',
#   '110516',
#   '8986',
# ...
#   '525',
#   'https://www.imdb.com/title/tt0080455',
#   'https://www.themoviedb.org/movie/525',
#   '3.8095238095238093',
#   'Saturday Night Live'),
#  (1221,
#   'Godfather: Part II The ',
#   'Crime|Drama',
#   '1974',
#   '71562',
#   '240',
#   'https://www.imdb.com/title/tt0071562',
#   'https://www.themoviedb.org/movie/240',
#   '4.25968992248062',
#   'Al Pacino Mafia'),
#  (1222,
#   'Full Metal Jacket ',
#   'Drama|War',
#   '1987',
#   '93058',
#   '600',
#   'https://www.imdb.com/title/tt0093058',
#   'https://www.themoviedb.org/movie/600',
#   '4.098039215686274',
#   'anti-war Vietnam'),
#  (1223,
#   'Grand Day Out with Wallace and Gromit A ',
#   'Adventure|Animation|Children|Comedy|Sci-Fi',
#   '1989',
#   '104361',
#   '530',
#   'https://www.imdb.com/title/tt0104361',
#   'https://www.themoviedb.org/movie/530',
#   '4.089285714285714',
#   'moon'),
#  (1224,
#   'Henry V ',
#   'Action|Drama|Romance|War',
#   '1989',
#   '97499',
#   '10705',
#   'https://www.imdb.com/title/tt0097499',
#   'https://www.themoviedb.org/movie/10705',
#   '4.0',
#   'Shakespeare'),
#  (1225,
#   'Amadeus ',
#   'Drama',
#   '1984',
#   '86879',
#   '279',
#   'https://www.imdb.com/title/tt0086879',
#   'https://www.themoviedb.org/movie/279',
#   '4.184210526315789',
#   'Mozart Salieri'),
#  (1226,
#   'Quiet Man The ',
#   'Drama|Romance',
#   '1952',
#   '45061',
#   '3109',
#   'https://www.imdb.com/title/tt0045061',
#   'https://www.themoviedb.org/movie/3109',
#   '3.5',
#   ' '),
#  (1227,
#   'Once Upon a Time in America ',
#   'Crime|Drama',
#   '1984',
#   '87843',
#   '311',
#   'https://www.imdb.com/title/tt0087843',
#   'https://www.themoviedb.org/movie/311',
#   '4.0625',
#   ' '),
#  (1228,
#   'Raging Bull ',
#   'Drama',
#   '1980',
#   '81398',
#   '1578',
#   'https://www.imdb.com/title/tt0081398',
#   'https://www.themoviedb.org/movie/1578',
#   '4.1875',
#   'boxing'),
#  (1230,
#   'Annie Hall ',
#   'Comedy|Romance',
#   '1977',
#   '75686',
#   '703',
#   'https://www.imdb.com/title/tt0075686',
#   'https://www.themoviedb.org/movie/703',
#   '3.8706896551724137',
#   'New York'),
#  (1231,
#   'Right Stuff The ',
#   'Drama',
#   '1983',
#   '86197',
#   '9549',
#   'https://www.imdb.com/title/tt0086197',
#   'https://www.themoviedb.org/movie/9549',
#   '3.8636363636363638',
#   'space NASA'),
#  (1232,
#   'Stalker ',
#   'Drama|Mystery|Sci-Fi',
#   '1979',
#   '79944',
#   '1398',
#   'https://www.imdb.com/title/tt0079944',
#   'https://www.themoviedb.org/movie/1398',
#   '3.625',
#   ' '),
#  (1233,
#   'Boot Das (Boat The) ',
#   'Action|Drama|War',
#   '1981',
#   '82096',
#   '387',
#   'https://www.imdb.com/title/tt0082096',
#   'https://www.themoviedb.org/movie/387',
#   '4.2125',
#   'submarine'),
#  (1234,
#   'Sting The ',
#   'Comedy|Crime',
#   '1973',
#   '70735',
#   '9277',
#   'https://www.imdb.com/title/tt0070735',
#   'https://www.themoviedb.org/movie/9277',
#   '3.9765625',
#   'The Entertainer'),
#  (1235,
#   'Harold and Maude ',
#   'Comedy|Drama|Romance',
#   '1971',
#   '67185',
#   '343',
#   'https://www.imdb.com/title/tt0067185',
#   'https://www.themoviedb.org/movie/343',
#   '4.288461538461538',
#   'May-December romance'),
#  (1236,
#   'Trust ',
#   'Comedy|Drama|Romance',
#   '1990',
#   '103130',
#   '37291',
#   'https://www.imdb.com/title/tt0103130',
#   'https://www.themoviedb.org/movie/37291',
#   '4.333333333333333',
#   ' '),
#  (1237,
#   'Seventh Seal The (Sjunde inseglet Det) ',
#   'Drama',
#   '1957',
#   '50976',
#   '490',
#   'https://www.imdb.com/title/tt0050976',
#   'https://www.themoviedb.org/movie/490',
#   '4.222222222222222',
#   'philosophical reflective chess existentialism cerebral atmospheric death'),
#  (1238,
#   'Local Hero ',
#   'Comedy',
#   '1983',
#   '85859',
#   '11235',
#   'https://www.imdb.com/title/tt0085859',
#   'https://www.themoviedb.org/movie/11235',
#   '4.055555555555555',
#   ' '),
#  (1240,
#   'Terminator The ',
#   'Action|Sci-Fi|Thriller',
#   '1984',
#   '88247',
#   '218',
#   'https://www.imdb.com/title/tt0088247',
#   'https://www.themoviedb.org/movie/218',
#   '3.8969465648854964',
#   'Sci-Fi time travel special effects tense robots artificial intelligence Action'),
#  (1241,
#   'Dead Alive (Braindead) ',
#   'Comedy|Fantasy|Horror',
#   '1992',
#   '103873',
#   '763',
#   'https://www.imdb.com/title/tt0103873',
#   'https://www.themoviedb.org/movie/763',
#   '4.05',
#   ' '),
#  (1242,
#   'Glory ',
#   'Drama|War',
#   '1989',
#   '97441',
#   '9665',
#   'https://www.imdb.com/title/tt0097441',
#   'https://www.themoviedb.org/movie/9665',
#   '4.170731707317073',
#   'Civil War'),
#  (1243,
#   'Rosencrantz and Guildenstern Are Dead ',
#   'Comedy|Drama',
#   '1990',
#   '100519',
#   '18971',
#   'https://www.imdb.com/title/tt0100519',
#   'https://www.themoviedb.org/movie/18971',
#   '3.96875',
#   'Shakespeare sort of'),
#  (1244,
#   'Manhattan ',
#   'Comedy|Drama|Romance',
#   '1979',
#   '79522',
#   '696',
#   'https://www.imdb.com/title/tt0079522',
#   'https://www.themoviedb.org/movie/696',
#   '4.106060606060606',
#   'black and white'),
#  (1245,
#   "Miller's Crossing ",
#   'Crime|Drama|Film-Noir|Thriller',
#   '1990',
#   '100150',
#   '379',
#   'https://www.imdb.com/title/tt0100150',
#   'https://www.themoviedb.org/movie/379',
#   '4.225',
#   'Mafia'),
#  (1246,
#   'Dead Poets Society ',
#   'Drama',
#   '1989',
#   '97165',
#   '207',
#   'https://www.imdb.com/title/tt0097165',
#   'https://www.themoviedb.org/movie/207',
#   '3.9593023255813953',
#   'High School highschool'),
#  (1247,
#   'Graduate The ',
#   'Comedy|Drama|Romance',
#   '1967',
#   '61722',
#   '37247',
#   'https://www.imdb.com/title/tt0061722',
#   'https://www.themoviedb.org/movie/37247',
#   '4.063291139240507',
#   'Simon and Garfunkel'),
#  (1248,
#   'Touch of Evil ',
#   'Crime|Film-Noir|Thriller',
#   '1958',
#   '52311',
#   '1480',
#   'https://www.imdb.com/title/tt0052311',
#   'https://www.themoviedb.org/movie/1480',
#   '4.264705882352941',
#   ' '),
#  (1249,
#   'Femme Nikita La (Nikita) ',
#   'Action|Crime|Romance|Thriller',
#   '1990',
#   '100263',
#   '9322',
#   'https://www.imdb.com/title/tt0100263',
#   'https://www.themoviedb.org/movie/9322',
#   '4.071428571428571',
#   'hit men'),
#  (1250,
#   'Bridge on the River Kwai The ',
#   'Adventure|Drama|War',
#   '1957',
#   '50212',
#   '826',
#   'https://www.imdb.com/title/tt0050212',
#   'https://www.themoviedb.org/movie/826',
#   '4.122222222222222',
#   'POW'),
#  (1755,
#   'Shooting Fish ',
#   'Comedy|Romance',
#   '1997',
#   '120122',
#   '25719',
#   'https://www.imdb.com/title/tt0120122',
#   'https://www.themoviedb.org/movie/25719',
#   '4.1',
#   ' '),
#  (1251,
#   '8 1/2 (8½) ',
#   'Drama|Fantasy',
#   '1963',
#   '56801',
#   '422',
#   'https://www.imdb.com/title/tt0056801',
#   'https://www.themoviedb.org/movie/422',
#   '4.071428571428571',
#   ' '),
#  (1252,
#   'Chinatown ',
#   'Crime|Film-Noir|Mystery|Thriller',
#   '1974',
#   '71315',
#   '829',
#   'https://www.imdb.com/title/tt0071315',
#   'https://www.themoviedb.org/movie/829',
#   '4.211864406779661',
#   'incest'),
#  (1253,
#   'Day the Earth Stood Still The ',
#   'Drama|Sci-Fi|Thriller',
#   '1951',
#   '43456',
#   '828',
#   'https://www.imdb.com/title/tt0043456',
#   'https://www.themoviedb.org/movie/828',
#   '3.82',
#   'aliens'),
#  (1254,
#   'Treasure of the Sierra Madre The ',
#   'Action|Adventure|Drama|Western',
#   '1948',
#   '40897',
#   '3090',
#   'https://www.imdb.com/title/tt0040897',
#   'https://www.themoviedb.org/movie/3090',
#   '3.65625',
#   'Cold'),
#  (1255,
#   'Bad Taste ',
#   'Comedy|Horror|Sci-Fi',
#   '1987',
#   '92610',
#   '9964',
#   'https://www.imdb.com/title/tt0092610',
#   'https://www.themoviedb.org/movie/9964',
#   '3.0',
#   ' '),
#  (1256,
#   'Duck Soup ',
#   'Comedy|Musical|War',
#   '1933',
#   '23969',
#   '3063',
#   'https://www.imdb.com/title/tt0023969',
#   'https://www.themoviedb.org/movie/3063',
#   '3.8043478260869565',
#   ' '),
#  (1257,
#   'Better Off Dead... ',
#   'Comedy|Romance',
#   '1985',
#   '88794',
#   '13667',
#   'https://www.imdb.com/title/tt0088794',
#   'https://www.themoviedb.org/movie/13667',
#   '3.685185185185185',
#   'skiing'),
#  (1258,
#   'Shining The ',
#   'Horror',
#   '1980',
#   '81505',
#   '694',
#   'https://www.imdb.com/title/tt0081505',
#   'https://www.themoviedb.org/movie/694',
#   '4.08256880733945',
#   'Horror suspense disturbing Stanley Kubrick atmospheric jack nicholson psychological Stephen King masterpiece'),
#  (1259,
#   'Stand by Me ',
#   'Adventure|Drama',
#   '1986',
#   '92005',
#   '235',
#   'https://www.imdb.com/title/tt0092005',
#   'https://www.themoviedb.org/movie/235',
#   '4.0054945054945055',
#   'Stephen King'),
#  (1260,
#   'M ',
#   'Crime|Film-Noir|Thriller',
#   '1931',
#   '22100',
#   '832',
#   'https://www.imdb.com/title/tt0022100',
#   'https://www.themoviedb.org/movie/832',
#   '3.7333333333333334',
#   'serial killer menacing mental illness creepy oninous atmospheric chilly'),
#  (1261,
#   'Evil Dead II (Dead by Dawn) ',
#   'Action|Comedy|Fantasy|Horror',
#   '1987',
#   '92991',
#   '765',
#   'https://www.imdb.com/title/tt0092991',
#   'https://www.themoviedb.org/movie/765',
#   '4.044117647058823',
#   ' '),
#  (1262,
#   'Great Escape The ',
#   'Action|Adventure|Drama|War',
#   '1963',
#   '57115',
#   '5925',
#   'https://www.imdb.com/title/tt0057115',
#   'https://www.themoviedb.org/movie/5925',
#   '4.127906976744186',
#   'POW'),
#  (1263,
#   'Deer Hunter The ',
#   'Drama|War',
#   '1978',
#   '77416',
#   '11778',
#   'https://www.imdb.com/title/tt0077416',
#   'https://www.themoviedb.org/movie/11778',
#   '3.8255813953488373',
#   'Vietnam'),
#  (1264,
#   'Diva ',
#   'Action|Drama|Mystery|Romance|Thriller',
#   '1981',
#   '82269',
#   '4485',
#   'https://www.imdb.com/title/tt0082269',
#   'https://www.themoviedb.org/movie/4485',
#   '3.8',
#   ' '),
#  (1265,
#   'Groundhog Day ',
#   'Comedy|Fantasy|Romance',
#   '1993',
#   '107048',
#   '137',
#   'https://www.imdb.com/title/tt0107048',
#   'https://www.themoviedb.org/movie/137',
#   '3.944055944055944',
#   ' '),
#  (1266,
#   'Unforgiven ',
#   'Drama|Western',
#   '1992',
#   '105695',
#   '33',
#   'https://www.imdb.com/title/tt0105695',
#   'https://www.themoviedb.org/movie/33',
#   '4.111111111111111',
#   'revenge'),
#  (1267,
#   'Manchurian Candidate The ',
#   'Crime|Thriller|War',
#   '1962',
#   '56218',
#   '982',
#   'https://www.imdb.com/title/tt0056218',
#   'https://www.themoviedb.org/movie/982',
#   '4.25',
#   'brainwashing assassination'),
#  (1268,
#   'Pump Up the Volume ',
#   'Comedy|Drama',
#   '1990',
#   '100436',
#   '8428',
#   'https://www.imdb.com/title/tt0100436',
#   'https://www.themoviedb.org/movie/8428',
#   '3.611111111111111',
#   ' '),
#  (1269,
#   'Arsenic and Old Lace ',
#   'Comedy|Mystery|Thriller',
#   '1944',
#   '36613',
#   '212',
#   'https://www.imdb.com/title/tt0036613',
#   'https://www.themoviedb.org/movie/212',
#   '3.8793103448275863',
#   'murder'),
#  (1270,
#   'Back to the Future ',
#   'Adventure|Comedy|Sci-Fi',
#   '1985',
#   '88763',
#   '105',
#   'https://www.imdb.com/title/tt0088763',
#   'https://www.themoviedb.org/movie/105',
#   '4.038011695906433',
#   'time travel'),
#  (1271,
#   'Fried Green Tomatoes ',
#   'Comedy|Crime|Drama',
#   '1991',
#   '101921',
#   '1633',
#   'https://www.imdb.com/title/tt0101921',
#   'https://www.themoviedb.org/movie/1633',
#   '3.5',
#   ' '),
#  (1272,
#   'Patton ',
#   'Drama|War',
#   '1970',
#   '66206',
#   '11202',
#   'https://www.imdb.com/title/tt0066206',
#   'https://www.themoviedb.org/movie/11202',
#   '4.121212121212121',
#   'World War II'),
#  (1273,
#   'Down by Law ',
#   'Comedy|Drama|Film-Noir',
#   '1986',
#   '90967',
#   '1554',
#   'https://www.imdb.com/title/tt0090967',
#   'https://www.themoviedb.org/movie/1554',
#   '4.045454545454546',
#   ' '),
#  (1274,
#   'Akira ',
#   'Action|Adventure|Animation|Sci-Fi',
#   '1988',
#   '94625',
#   '149',
#   'https://www.imdb.com/title/tt0094625',
#   'https://www.themoviedb.org/movie/149',
#   '3.7435897435897436',
#   'visually stunning anime animation'),
#  (1275,
#   'Highlander ',
#   'Action|Adventure|Fantasy',
#   '1986',
#   '91203',
#   '8009',
#   'https://www.imdb.com/title/tt0091203',
#   'https://www.themoviedb.org/movie/8009',
#   '3.7291666666666665',
#   ' '),
#  (1276,
#   'Cool Hand Luke ',
#   'Drama',
#   '1967',
#   '61512',
#   '903',
#   'https://www.imdb.com/title/tt0061512',
#   'https://www.themoviedb.org/movie/903',
#   '4.271929824561403',
#   'prison'),
#  (1277,
#   'Cyrano de Bergerac ',
#   'Comedy|Drama|Romance',
#   '1990',
#   '99334',
#   '11673',
#   'https://www.imdb.com/title/tt0099334',
#   'https://www.themoviedb.org/movie/11673',
#   '4.125',
#   'In Netflix queue'),
#  (1278,
#   'Young Frankenstein ',
#   'Comedy|Fantasy',
#   '1974',
#   '72431',
#   '3034',
#   'https://www.imdb.com/title/tt0072431',
#   'https://www.themoviedb.org/movie/3034',
#   '3.9927536231884058',
#   'spoof'),
#  (1279,
#   'Night on Earth ',
#   'Comedy|Drama',
#   '1991',
#   '102536',
#   '339',
#   'https://www.imdb.com/title/tt0102536',
#   'https://www.themoviedb.org/movie/339',
#   '4.125',
#   ' '),
#  (1280,
#   'Raise the Red Lantern (Da hong deng long gao gao gua) ',
#   'Drama',
#   '1991',
#   '101640',
#   '10404',
#   'https://www.imdb.com/title/tt0101640',
#   'https://www.themoviedb.org/movie/10404',
#   '4.333333333333333',
#   'In Netflix queue'),
#  (1281,
#   'Great Dictator The ',
#   'Comedy|Drama|War',
#   '1940',
#   '32553',
#   '914',
#   'https://www.imdb.com/title/tt0032553',
#   'https://www.themoviedb.org/movie/914',
#   '4.133333333333334',
#   'Nazis'),
#  (1282,
#   'Fantasia ',
#   'Animation|Children|Fantasy|Musical',
#   '1940',
#   '32455',
#   '756',
#   'https://www.imdb.com/title/tt0032455',
#   'https://www.themoviedb.org/movie/756',
#   '3.7830188679245285',
#   'Disney'),
#  (1283,
#   'High Noon ',
#   'Drama|Western',
#   '1952',
#   '44706',
#   '288',
#   'https://www.imdb.com/title/tt0044706',
#   'https://www.themoviedb.org/movie/288',
#   '4.2105263157894735',
#   'gunfight'),
#  (1284,
#   'Big Sleep The ',
#   'Crime|Film-Noir|Mystery',
#   '1946',
#   '38355',
#   '910',
#   'https://www.imdb.com/title/tt0038355',
#   'https://www.themoviedb.org/movie/910',
#   '4.142857142857143',
#   'Hammett'),
#  (1285,
#   'Heathers ',
#   'Comedy',
#   '1989',
#   '97493',
#   '2640',
#   'https://www.imdb.com/title/tt0097493',
#   'https://www.themoviedb.org/movie/2640',
#   '3.731707317073171',
#   'high school'),
#  (1286,
#   'Somewhere in Time ',
#   'Drama|Romance',
#   '1980',
#   '81534',
#   '16633',
#   'https://www.imdb.com/title/tt0081534',
#   'https://www.themoviedb.org/movie/16633',
#   '3.0714285714285716',
#   ' '),
#  (1287,
#   'Ben-Hur ',
#   'Action|Adventure|Drama',
#   '1959',
#   '52618',
#   '665',
#   'https://www.imdb.com/title/tt0052618',
#   'https://www.themoviedb.org/movie/665',
#   '3.9411764705882355',
#   ' '),
#  (1288,
#   'This Is Spinal Tap ',
#   'Comedy',
#   '1984',
#   '88258',
#   '11031',
#   'https://www.imdb.com/title/tt0088258',
#   'https://www.themoviedb.org/movie/11031',
#   '4.015151515151516',
#   'music mockumentary heavy metal'),
#  (1289,
#   'Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) ',
#   'Documentary',
#   '1983',
#   '85809',
#   '11314',
#   'https://www.imdb.com/title/tt0085809',
#   'https://www.themoviedb.org/movie/11314',
#   '3.8636363636363638',
#   ' '),
#  (1290,
#   'Some Kind of Wonderful ',
#   'Drama|Romance',
#   '1987',
#   '94006',
#   '15143',
#   'https://www.imdb.com/title/tt0094006',
#   'https://www.themoviedb.org/movie/15143',
#   '3.35',
#   ' '),
#  (1291,
#   'Indiana Jones and the Last Crusade ',
#   'Action|Adventure',
#   '1989',
#   '97576',
#   '89',
#   'https://www.imdb.com/title/tt0097576',
#   'https://www.themoviedb.org/movie/89',
#   '4.046428571428572',
#   'archaeology Holy Grail'),
#  (1292,
#   'Being There ',
#   'Comedy|Drama',
#   '1979',
#   '78841',
#   '10322',
#   'https://www.imdb.com/title/tt0078841',
#   'https://www.themoviedb.org/movie/10322',
#   '3.95',
#   'television'),
#  (1295,
#   'Unbearable Lightness of Being The ',
#   'Drama',
#   '1988',
#   '96332',
#   '10644',
#   'https://www.imdb.com/title/tt0096332',
#   'https://www.themoviedb.org/movie/10644',
#   '3.227272727272727',
#   ' '),
#  (1296,
#   'Room with a View A ',
#   'Drama|Romance',
#   '1986',
#   '91867',
#   '11257',
#   'https://www.imdb.com/title/tt0091867',
#   'https://www.themoviedb.org/movie/11257',
#   '3.7058823529411766',
#   'E. M. Forster'),
#  (1297,
#   'Real Genius ',
#   'Comedy',
#   '1985',
#   '89886',
#   '14370',
#   'https://www.imdb.com/title/tt0089886',
#   'https://www.themoviedb.org/movie/14370',
#   '3.675',
#   ' '),
#  (1298,
#   'Pink Floyd: The Wall ',
#   'Drama|Musical',
#   '1982',
#   '84503',
#   '12104',
#   'https://www.imdb.com/title/tt0084503',
#   'https://www.themoviedb.org/movie/12104',
#   '3.760869565217391',
#   ' '),
#  (1299,
#   'Killing Fields The ',
#   'Drama|War',
#   '1984',
#   '87553',
#   '625',
#   'https://www.imdb.com/title/tt0087553',
#   'https://www.themoviedb.org/movie/625',
#   '4.017857142857143',
#   'Vietnam Cambodia'),
#  ...]

# %%
##count movieids and group them based on their year of release
execute_query(conn,'SELECT Year_of_Release,COUNT(movieId) FROM movie_data GROUP BY Year_of_Release ORDER BY Year_of_Release;')
# Out:
# Query executed
# [(' ', 12),
#  ('1902', 1),
#  ('1903', 1),
#  ('1908', 1),
#  ('1915', 1),
#  ('1916', 4),
#  ('1917', 1),
#  ('1919', 1),
#  ('1920', 2),
#  ('1921', 1),
#  ('1922', 1),
#  ('1923', 4),
#  ('1924', 5),
#  ('1925', 4),
#  ('1926', 5),
#  ('1927', 7),
#  ('1928', 4),
#  ('1929', 4),
#  ('1930', 5),
#  ('1931', 14),
#  ('1932', 9),
#  ('1933', 12),
#  ('1934', 11),
#  ('1935', 13),
#  ('1936', 18),
#  ('1937', 16),
#  ('1938', 15),
#  ('1939', 23),
#  ('1940', 25),
#  ('1941', 18),
#  ('1942', 23),
#  ('1943', 10),
#  ('1944', 16),
#  ('1945', 17),
#  ('1946', 23),
#  ('1947', 20),
#  ('1948', 20),
#  ('1949', 25),
#  ('1950', 21),
#  ('1951', 22),
#  ('1952', 16),
#  ('1953', 30),
#  ('1954', 23),
#  ('1955', 36),
#  ('1956', 30),
#  ('1957', 33),
#  ('1958', 31),
#  ('1959', 37),
#  ('1960', 37),
#  ('1961', 34),
#  ('1962', 40),
#  ('1963', 39),
#  ('1964', 43),
#  ('1965', 47),
#  ('1966', 42),
#  ('1967', 42),
#  ('1968', 42),
#  ('1969', 35),
#  ('1970', 33),
#  ('1971', 47),
#  ('1972', 39),
#  ('1973', 58),
#  ('1973 ', 1),
#  ('1974', 45),
#  ('1975', 42),
#  ('1976', 44),
#  ('1977', 63),
#  ('1978', 59),
#  ('1979', 69),
#  ('1980', 89),
#  ('1981', 92),
#  ('1982', 87),
#  ('1983', 83),
#  ('1984', 101),
#  ('1985', 126),
#  ('1986', 139),
#  ('1987', 153),
#  ('1988', 165),
#  ('1989', 142),
#  ('1990', 147),
#  ('1991', 147),
#  ('1992', 167),
#  ('1993', 198),
#  ('1994', 237),
#  ('1995', 258),
#  ('1995 ', 1),
#  ('1996', 276),
#  ('1997', 260),
#  ('1998', 257),
#  ('1998 ', 1),
#  ('1999', 262),
#  ('1999 ', 1),
#  ('2000', 283),
#  ('2001', 294),
#  ('2002', 311),
#  ('2003', 279),
#  ('2004', 279),
#  ('2005', 273),
#  ('2006', 295),
#  ('2006–2007', 1),
#  ('2007', 282),
#  ('2007 ', 2),
#  ('2008', 268),
#  ('2008 ', 1),
#  ('2009', 282),
#  ('2010', 247),
#  ('2011', 252),
#  ('2011 ', 2),
#  ('2012', 232),
#  ('2012 ', 1),
#  ('2013', 239),
#  ('2014', 277),
#  ('2014 ', 1),
#  ('2015', 274),
#  ('2016', 218),
#  ('2017', 147),
#  ('2018', 41)]
